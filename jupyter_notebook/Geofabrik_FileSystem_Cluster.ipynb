# %%
import geopandas as gpd
import os
from glob import glob
import pandas as pd
import requests
import zipfile
import time
import json
import shapely

# %%
project_folder_path = r"/work/mhealthresearchgroup/Geofabrik"

# %%
download_folder_path = os.path.join(project_folder_path, "download")

# %%
unzipped_folder_path = os.path.join(project_folder_path, "unzipped")

# %%
organized_data_folder_path = os.path.join(project_folder_path, "organized_landmarks")

# %%
combined_data_folder_path = os.path.join(project_folder_path, "organized_landmarks_combined")

# %%
geo_map_path = "/home/li.jix/repo/geofabrik_landmark_map/map/Amenity List - combined_GF_cleaned.csv"

# %%
base_url = "http://download.geofabrik.de/north-america/us/"

# %%
update = False

# %%
# create root folder
def create_folder(p):
    if not os.path.exists(p):
        os.makedirs(p)

# %% [markdown]
# ### 1. Download, unzip, and store Geofabrik data from all states

# %%
# download
def get_shp_file_link(state):
    if state == 'united states virgin islands':
        state_name = "us-virgin-islands"
    elif state == 'norcal' or state == 'socal':
        state_name = "california/"+state
    else:
        state_name = state.replace(" ", "-")
    return base_url + state_name + "-latest-free.shp.zip"

# %%
def download_state_zipfile(state, url):
    r = requests.get(url, allow_redirects=True)
    save_path = os.path.join(download_folder_path, state+'.shp.zip')
    open(save_path, 'wb').write(r.content)
    return save_path

# %%
def unzip_file(zipfile_path, zip_to_path):
    with zipfile.ZipFile(zipfile_path, 'r') as zip_ref:
        zip_ref.extractall(zip_to_path)

# %%
l = "alabama, alaska, arizona, arkansas, norcal, socal, colorado, connecticut, delaware, district of columbia, florida, georgia, hawaii, idaho, illinois, indiana, iowa, kansas, kentucky, louisiana, maine, maryland, massachusetts, michigan, minnesota, mississippi, missouri, montana, nebraska, nevada, new hampshire, new jersey, new mexico, new york, north carolina, north dakota, ohio, oklahoma, oregon, pennsylvania, puerto rico, rhode island, south carolina, south dakota, tennessee, texas, united states virgin islands, utah, vermont, virginia, washington, west virginia, wisconsin, wyoming"
state_list = l.split(", ")

# %%
start = time.time()
print("=================")
print("Download Geofabrik data for all states to {}".format(download_folder_path))
print("Unzip Geofabrik data for all states to {}".format(unzipped_folder_path))
print("=================")

create_folder(download_folder_path)
create_folder(unzipped_folder_path)
for state in state_list:
    print(state)
    # update or not
    zip_to_path = os.path.join(unzipped_folder_path, state)
    if not update: # skip state if unzipped file exists
        if os.path.exists(zip_to_path):
            print("skip because unzipped file exists")
            continue
        
    
    # download
    url = get_shp_file_link(state)
    download_save_path = download_state_zipfile(state, url)
    print("    "+url)
    print("    "+"Downloaded to : " + download_save_path)
    
    # unzip
    zipfile_path = os.path.join(download_folder_path, state + '.shp.zip')
    unzip_file(zipfile_path, zip_to_path)
    print("    "+"Unzipped to : " + zip_to_path)
    
end = time.time()
print(f"Runtime of the program is {end - start}")
# Out:
# =================
# Download Geofabrik data for all states to /work/mhealthresearchgroup/Geofabrik/download
# Unzip Geofabrik data for all states to /work/mhealthresearchgroup/Geofabrik/unzipped
# =================
# alabama
# skip because unzipped file exists
# alaska
# skip because unzipped file exists
# arizona
# skip because unzipped file exists
# arkansas
# skip because unzipped file exists
# norcal
# skip because unzipped file exists
# socal
# skip because unzipped file exists
# colorado
# skip because unzipped file exists
# connecticut
# skip because unzipped file exists
# delaware
# skip because unzipped file exists
# district of columbia
# skip because unzipped file exists
# florida
# skip because unzipped file exists
# georgia
# skip because unzipped file exists
# hawaii
# skip because unzipped file exists
# idaho
# skip because unzipped file exists
# illinois
# skip because unzipped file exists
# indiana
# skip because unzipped file exists
# iowa
#     http://download.geofabrik.de/north-america/us/iowa-latest-free.shp.zip
#     Downloaded to : /work/mhealthresearchgroup/Geofabrik/download/iowa.shp.zip
#     Unzipped to : /work/mhealthresearchgroup/Geofabrik/unzipped/iowa
# kansas
#     http://download.geofabrik.de/north-america/us/kansas-latest-free.shp.zip
#     Downloaded to : /work/mhealthresearchgroup/Geofabrik/download/kansas.shp.zip
#     Unzipped to : /work/mhealthresearchgroup/Geofabrik/unzipped/kansas
# kentucky
#     http://download.geofabrik.de/north-america/us/kentucky-latest-free.shp.zip
#     Downloaded to : /work/mhealthresearchgroup/Geofabrik/download/kentucky.shp.zip
#     Unzipped to : /work/mhealthresearchgroup/Geofabrik/unzipped/kentucky
# louisiana
#     http://download.geofabrik.de/north-america/us/louisiana-latest-free.shp.zip
#     Downloaded to : /work/mhealthresearchgroup/Geofabrik/download/louisiana.shp.zip
#     Unzipped to : /work/mhealthresearchgroup/Geofabrik/unzipped/louisiana
# maine
#     http://download.geofabrik.de/north-america/us/maine-latest-free.shp.zip
#     Downloaded to : /work/mhealthresearchgroup/Geofabrik/download/maine.shp.zip
#     Unzipped to : /work/mhealthresearchgroup/Geofabrik/unzipped/maine
# maryland
#     http://download.geofabrik.de/north-america/us/maryland-latest-free.shp.zip
#     Downloaded to : /work/mhealthresearchgroup/Geofabrik/download/maryland.shp.zip
#     Unzipped to : /work/mhealthresearchgroup/Geofabrik/unzipped/maryland
# massachusetts
#     http://download.geofabrik.de/north-america/us/massachusetts-latest-free.shp.zip
#     Downloaded to : /work/mhealthresearchgroup/Geofabrik/download/massachusetts.shp.zip
#     Unzipped to : /work/mhealthresearchgroup/Geofabrik/unzipped/massachusetts
# michigan
#     http://download.geofabrik.de/north-america/us/michigan-latest-free.shp.zip
#     Downloaded to : /work/mhealthresearchgroup/Geofabrik/download/michigan.shp.zip
#     Unzipped to : /work/mhealthresearchgroup/Geofabrik/unzipped/michigan
# minnesota
#     http://download.geofabrik.de/north-america/us/minnesota-latest-free.shp.zip
#     Downloaded to : /work/mhealthresearchgroup/Geofabrik/download/minnesota.shp.zip
#     Unzipped to : /work/mhealthresearchgroup/Geofabrik/unzipped/minnesota
# mississippi
#     http://download.geofabrik.de/north-america/us/mississippi-latest-free.shp.zip
#     Downloaded to : /work/mhealthresearchgroup/Geofabrik/download/mississippi.shp.zip
#     Unzipped to : /work/mhealthresearchgroup/Geofabrik/unzipped/mississippi
# missouri
#     http://download.geofabrik.de/north-america/us/missouri-latest-free.shp.zip
#     Downloaded to : /work/mhealthresearchgroup/Geofabrik/download/missouri.shp.zip
#     Unzipped to : /work/mhealthresearchgroup/Geofabrik/unzipped/missouri
# montana
#     http://download.geofabrik.de/north-america/us/montana-latest-free.shp.zip
#     Downloaded to : /work/mhealthresearchgroup/Geofabrik/download/montana.shp.zip
#     Unzipped to : /work/mhealthresearchgroup/Geofabrik/unzipped/montana
# nebraska
#     http://download.geofabrik.de/north-america/us/nebraska-latest-free.shp.zip
#     Downloaded to : /work/mhealthresearchgroup/Geofabrik/download/nebraska.shp.zip
#     Unzipped to : /work/mhealthresearchgroup/Geofabrik/unzipped/nebraska
# nevada
#     http://download.geofabrik.de/north-america/us/nevada-latest-free.shp.zip
#     Downloaded to : /work/mhealthresearchgroup/Geofabrik/download/nevada.shp.zip
#     Unzipped to : /work/mhealthresearchgroup/Geofabrik/unzipped/nevada
# new hampshire
#     http://download.geofabrik.de/north-america/us/new-hampshire-latest-free.shp.zip
#     Downloaded to : /work/mhealthresearchgroup/Geofabrik/download/new hampshire.shp.zip
#     Unzipped to : /work/mhealthresearchgroup/Geofabrik/unzipped/new hampshire
# new jersey
#     http://download.geofabrik.de/north-america/us/new-jersey-latest-free.shp.zip
#     Downloaded to : /work/mhealthresearchgroup/Geofabrik/download/new jersey.shp.zip
#     Unzipped to : /work/mhealthresearchgroup/Geofabrik/unzipped/new jersey
# new mexico
#     http://download.geofabrik.de/north-america/us/new-mexico-latest-free.shp.zip
#     Downloaded to : /work/mhealthresearchgroup/Geofabrik/download/new mexico.shp.zip
#     Unzipped to : /work/mhealthresearchgroup/Geofabrik/unzipped/new mexico
# new york
#     http://download.geofabrik.de/north-america/us/new-york-latest-free.shp.zip
#     Downloaded to : /work/mhealthresearchgroup/Geofabrik/download/new york.shp.zip
#     Unzipped to : /work/mhealthresearchgroup/Geofabrik/unzipped/new york
# north carolina
#     http://download.geofabrik.de/north-america/us/north-carolina-latest-free.shp.zip
#     Downloaded to : /work/mhealthresearchgroup/Geofabrik/download/north carolina.shp.zip
#     Unzipped to : /work/mhealthresearchgroup/Geofabrik/unzipped/north carolina
# north dakota
#     http://download.geofabrik.de/north-america/us/north-dakota-latest-free.shp.zip
#     Downloaded to : /work/mhealthresearchgroup/Geofabrik/download/north dakota.shp.zip
#     Unzipped to : /work/mhealthresearchgroup/Geofabrik/unzipped/north dakota
# ohio
#     http://download.geofabrik.de/north-america/us/ohio-latest-free.shp.zip
#     Downloaded to : /work/mhealthresearchgroup/Geofabrik/download/ohio.shp.zip
#     Unzipped to : /work/mhealthresearchgroup/Geofabrik/unzipped/ohio
# oklahoma
#     http://download.geofabrik.de/north-america/us/oklahoma-latest-free.shp.zip
#     Downloaded to : /work/mhealthresearchgroup/Geofabrik/download/oklahoma.shp.zip
#     Unzipped to : /work/mhealthresearchgroup/Geofabrik/unzipped/oklahoma
# oregon
#     http://download.geofabrik.de/north-america/us/oregon-latest-free.shp.zip
#     Downloaded to : /work/mhealthresearchgroup/Geofabrik/download/oregon.shp.zip
#     Unzipped to : /work/mhealthresearchgroup/Geofabrik/unzipped/oregon
# pennsylvania
#     http://download.geofabrik.de/north-america/us/pennsylvania-latest-free.shp.zip
#     Downloaded to : /work/mhealthresearchgroup/Geofabrik/download/pennsylvania.shp.zip
#     Unzipped to : /work/mhealthresearchgroup/Geofabrik/unzipped/pennsylvania
# puerto rico
#     http://download.geofabrik.de/north-america/us/puerto-rico-latest-free.shp.zip
#     Downloaded to : /work/mhealthresearchgroup/Geofabrik/download/puerto rico.shp.zip
#     Unzipped to : /work/mhealthresearchgroup/Geofabrik/unzipped/puerto rico
# rhode island
#     http://download.geofabrik.de/north-america/us/rhode-island-latest-free.shp.zip
#     Downloaded to : /work/mhealthresearchgroup/Geofabrik/download/rhode island.shp.zip
#     Unzipped to : /work/mhealthresearchgroup/Geofabrik/unzipped/rhode island
# south carolina
#     http://download.geofabrik.de/north-america/us/south-carolina-latest-free.shp.zip
#     Downloaded to : /work/mhealthresearchgroup/Geofabrik/download/south carolina.shp.zip
#     Unzipped to : /work/mhealthresearchgroup/Geofabrik/unzipped/south carolina
# south dakota
#     http://download.geofabrik.de/north-america/us/south-dakota-latest-free.shp.zip
#     Downloaded to : /work/mhealthresearchgroup/Geofabrik/download/south dakota.shp.zip
#     Unzipped to : /work/mhealthresearchgroup/Geofabrik/unzipped/south dakota
# tennessee
#     http://download.geofabrik.de/north-america/us/tennessee-latest-free.shp.zip
#     Downloaded to : /work/mhealthresearchgroup/Geofabrik/download/tennessee.shp.zip
#     Unzipped to : /work/mhealthresearchgroup/Geofabrik/unzipped/tennessee
# texas
#     http://download.geofabrik.de/north-america/us/texas-latest-free.shp.zip
#     Downloaded to : /work/mhealthresearchgroup/Geofabrik/download/texas.shp.zip
#     Unzipped to : /work/mhealthresearchgroup/Geofabrik/unzipped/texas
# united states virgin islands
#     http://download.geofabrik.de/north-america/us/us-virgin-islands-latest-free.shp.zip
#     Downloaded to : /work/mhealthresearchgroup/Geofabrik/download/united states virgin islands.shp.zip
#     Unzipped to : /work/mhealthresearchgroup/Geofabrik/unzipped/united states virgin islands
# utah
#     http://download.geofabrik.de/north-america/us/utah-latest-free.shp.zip
#     Downloaded to : /work/mhealthresearchgroup/Geofabrik/download/utah.shp.zip
#     Unzipped to : /work/mhealthresearchgroup/Geofabrik/unzipped/utah
# vermont
#     http://download.geofabrik.de/north-america/us/vermont-latest-free.shp.zip
#     Downloaded to : /work/mhealthresearchgroup/Geofabrik/download/vermont.shp.zip
#     Unzipped to : /work/mhealthresearchgroup/Geofabrik/unzipped/vermont
# virginia
#     http://download.geofabrik.de/north-america/us/virginia-latest-free.shp.zip
#     Downloaded to : /work/mhealthresearchgroup/Geofabrik/download/virginia.shp.zip
#     Unzipped to : /work/mhealthresearchgroup/Geofabrik/unzipped/virginia
# washington
#     http://download.geofabrik.de/north-america/us/washington-latest-free.shp.zip
#     Downloaded to : /work/mhealthresearchgroup/Geofabrik/download/washington.shp.zip
#     Unzipped to : /work/mhealthresearchgroup/Geofabrik/unzipped/washington
# west virginia
#     http://download.geofabrik.de/north-america/us/west-virginia-latest-free.shp.zip
#     Downloaded to : /work/mhealthresearchgroup/Geofabrik/download/west virginia.shp.zip
#     Unzipped to : /work/mhealthresearchgroup/Geofabrik/unzipped/west virginia
# wisconsin
#     http://download.geofabrik.de/north-america/us/wisconsin-latest-free.shp.zip
#     Downloaded to : /work/mhealthresearchgroup/Geofabrik/download/wisconsin.shp.zip
#     Unzipped to : /work/mhealthresearchgroup/Geofabrik/unzipped/wisconsin
# wyoming
#     http://download.geofabrik.de/north-america/us/wyoming-latest-free.shp.zip
#     Downloaded to : /work/mhealthresearchgroup/Geofabrik/download/wyoming.shp.zip
#     Unzipped to : /work/mhealthresearchgroup/Geofabrik/unzipped/wyoming
# Runtime of the program is 1137.6284246444702

# %%
923/60
# Out:
# 15.383333333333333

# %% [markdown]
# ### 2. Parse Geofabrik map

# %%
# first run "clean_csv_map" and use "Amenity List - combined_GF_clean.csv"

# %%
# convert csv map to json map
map_dict = {"unique_list": [], "map": {}}

with open(geo_map_path) as fp:
    Lines = fp.readlines()
    for line in Lines:  # skip head line
        line_list = line.split(",")
        label_1st = line_list[0]
        label_2nd = line_list[1]
        label_3rd = line_list[2]
        if len(label_1st) > 0:
            level1 = label_1st
            map_dict['map'][level1] = dict()
            map_dict['unique_list'].append(label_1st) 
        if len(label_2nd) > 0:
            level2 = label_2nd
            map_dict['map'][level1][level2] = dict()
            map_dict['unique_list'].append(label_2nd) 
        if len(label_3rd) > 0:
            line_list_lvl3 = [x for x in line_list if (len(x) > 0) and (x != '\n')]
            map_dict['map'][level1][level2][label_3rd] = line_list_lvl3[1:]
            map_dict['unique_list']+= line_list_lvl3

# %%
map_dict
# Out:
# {'unique_list': ['residential',
#   'residential',
#   'apartment',
#   'studio',
#   'dormitory',
#   'dorm',
#   'fraternity_house',
#   'fraternity',
#   'house',
#   'carriage_house',
#   'deckhouse',
#   'semidetached_house',
#   'townhouse',
#   'condominium',
#   'condo',
#   'condominum',
#   'affordable_housing',
#   'pavillion',
#   'residential',
#   'bungalow',
#   'cabin',
#   'hut',
#   'lodge',
#   'mansion',
#   'mobile_home',
#   'residence',
#   'static_caravan',
#   'group_housing',
#   'housing',
#   'home',
#   'building',
#   'building',
#   'historic_building',
#   'county_building',
#   'department_building',
#   'music_building',
#   'skyscraper',
#   'cultural_center',
#   'engineering_building',
#   'organization',
#   'maintenance_building',
#   'service',
#   'education',
#   'college',
#   'college_building',
#   'childcare',
#   'childcare_facility',
#   'day_care',
#   'preschool',
#   'kindergarten',
#   'school',
#   'high_school',
#   'music_school',
#   'classroom',
#   'library',
#   'university_library',
#   'university',
#   'education',
#   'academic',
#   'academic_building',
#   'student_center',
#   'health',
#   'clinic',
#   'dentist',
#   'dentist_office',
#   'doctor',
#   'doctor',
#   'hospital',
#   'pharmacy',
#   'health_center',
#   'nursing_home',
#   'medical',
#   'health',
#   'healthcare',
#   'mental_health_clinic',
#   'religion',
#   'religion',
#   'christian',
#   'christian_anglican',
#   'christian_catholic',
#   'christian_evangelical',
#   'christian_lutheran',
#   'christian_methodist',
#   'christian_orthodox',
#   'christian_protestant',
#   'hindu',
#   'jewish',
#   'muslim',
#   'muslim_shia',
#   'muslim_sunni',
#   'sikh',
#   'taoist',
#   'cathedral',
#   'chapel',
#   'church',
#   'monastery',
#   'mosque',
#   'buddhist',
#   'presbytery',
#   'religiou',
#   'fraturnity',
#   'presbyterian\n',
#   'transportation',
#   'transportation',
#   'airport',
#   'airfield',
#   'helipad',
#   'apron',
#   'bus_station',
#   'bus_stop',
#   'train_station',
#   'railway_station',
#   'railway_halt',
#   'tram_stop',
#   'subway_entrance',
#   'car_rental',
#   'car_sharing',
#   'taxi',
#   'taxi_rank',
#   'ferry_terminal',
#   'fuel',
#   'service',
#   'gas_station',
#   'parking',
#   'garage',
#   'parking_multistorey',
#   'parking_underground',
#   'vending_parking',
#   'parking_site',
#   'parking_lot',
#   'car_park',
#   'parking_structure',
#   'parking_space',
#   'parking_bicycle',
#   'finance',
#   'bank',
#   'credit_union',
#   'atm',
#   'insurance',
#   'other',
#   'government',
#   'courthouse',
#   'embassy',
#   'municipal',
#   'town_hall',
#   'city_hall',
#   'municipial',
#   'police',
#   'police_station',
#   'post_office',
#   'post_box',
#   'us_post_office',
#   'community_centre',
#   'community_center',
#   'fire_station',
#   'fire_department',
#   'prison',
#   'jail_house',
#   'jail',
#   'telephone',
#   'public_building',
#   'commercial',
#   'leisure',
#   'cinema',
#   'bar',
#   'pub',
#   'nightclub',
#   'aquarium',
#   'theatre',
#   'theater',
#   'concert_hall',
#   'outdoor_stage',
#   'auditorium',
#   'theme_park',
#   'zoo',
#   'museum',
#   'arts_centre',
#   'arts_center',
#   'art_building',
#   'casino',
#   'shopping',
#   'kiosk',
#   'newsagent',
#   'vending_machine',
#   'vending_cigarette',
#   'vending_any',
#   'shop',
#   'clothe',
#   'shoe_shop',
#   'outdoor_shop',
#   'bicycle_shop',
#   'bookshop',
#   'car_dealership',
#   'computer_shop',
#   'furniture_shop',
#   'gift_shop',
#   'jeweller',
#   'mobile_phone_shop',
#   'sports_shop',
#   'stationery',
#   'toy_shop',
#   'video_shop',
#   'store',
#   'retail',
#   'optician',
#   'garden_centre',
#   'general',
#   'florist',
#   'chemist',
#   'retail_store',
#   'shopping',
#   'jeweler\n',
#   'supermarket',
#   'butcher',
#   'convenience',
#   'greengrocer',
#   'grocery_store',
#   'grocery',
#   'mall',
#   'department_store',
#   'market_place',
#   'shopping_center',
#   'market',
#   'food',
#   'beverage',
#   'biergarten',
#   'deli',
#   'restaurant',
#   'food_court',
#   'cafe',
#   'coffee_shop',
#   'cafeteria',
#   'bakery',
#   'fast_food',
#   'dining_hall',
#   'food',
#   'food_and_drink',
#   'lifestyle',
#   'laundry',
#   'laundromat',
#   'beauty_shop',
#   'hairdresser',
#   'car_wash',
#   'car_repair',
#   'hotel',
#   'hostel',
#   'motel',
#   'bed_and_breakfast',
#   'guesthouse',
#   'chalet',
#   'inn',
#   'recycling',
#   'recycling_clothe',
#   'recycling_glas',
#   'recycling_metal',
#   'recycling_paper',
#   'stadium',
#   'veterinary',
#   'travel_agent',
#   'self_storage',
#   'storage_unit',
#   'storage_facility',
#   'self-storage',
#   'storage',
#   'storage_building',
#   'storage_rental',
#   'other',
#   'commercial',
#   'busines',
#   'busines',
#   'industrial',
#   'office',
#   'company',
#   'verizon_building',
#   'factory',
#   'quarry',
#   'power_station',
#   'manufacture',
#   'manufacturing',
#   'brewery',
#   'power_plant',
#   'convention_center',
#   'convention_centre',
#   'conference_center',
#   'recreational',
#   'indoor',
#   'sports_centre',
#   'sports_house',
#   'sports_complex',
#   'sports_hall',
#   'recreational_center',
#   'gymnasium',
#   'gym',
#   'recreation_center',
#   'sport',
#   'swimming_pool',
#   'outdoor',
#   'nature',
#   'beach',
#   'cave_entrance',
#   'cliff',
#   'glacier',
#   'peak',
#   'spring',
#   'tree',
#   'volcano',
#   'nature_reserve',
#   'forest',
#   'meadow',
#   'orchard',
#   'vineyard',
#   'scrub',
#   'gras',
#   'national_park',
#   'basin',
#   'water',
#   'waterfall',
#   'reservoir',
#   'river',
#   'dock',
#   'glacier',
#   'wetland',
#   'park',
#   'allotment',
#   'recreation_ground',
#   'village_green',
#   'garden',
#   'nursery',
#   'plant_nursery',
#   'arboretum',
#   'farm',
#   'farmland',
#   'farmyard',
#   'bicycle_rental',
#   'golf_course',
#   'dog_park',
#   'ice_rink',
#   'ice_skating_rink',
#   'skating_rink',
#   'picnic_site',
#   'pitch',
#   'playground',
#   'track',
#   'viewpoint',
#   'observation_tower',
#   'attraction',
#   'monument',
#   'memorial',
#   'castle',
#   'ruin',
#   'archaeological',
#   'battlefield',
#   'fort',
#   'aerialway_station',
#   'hunting_stand',
#   'graveyard',
#   'cemetery',
#   'tennis_court',
#   'shelter',
#   'alpine_hut',
#   'camp_site',
#   'caravan_site',
#   'tourism',
#   'tourist_info',
#   'tourist_map',
#   'tourist_board',
#   'tourist_guidepost',
#   'country_club'],
#  'map': {'residential': {'residential': {'apartment': ['studio'],
#     'dormitory': ['dorm', 'fraternity_house', 'fraternity'],
#     'house': ['carriage_house',
#      'deckhouse',
#      'semidetached_house',
#      'townhouse',
#      'condominium',
#      'condo',
#      'condominum',
#      'affordable_housing',
#      'pavillion'],
#     'residential': ['bungalow',
#      'cabin',
#      'hut',
#      'lodge',
#      'mansion',
#      'mobile_home',
#      'residence',
#      'static_caravan',
#      'group_housing',
#      'housing'],
#     'home': []},
#    'building': {'building': ['historic_building',
#      'county_building',
#      'department_building',
#      'music_building',
#      'skyscraper',
#      'cultural_center',
#      'engineering_building',
#      'organization',
#      'maintenance_building']}},
#   'service': {'education': {'college': ['college_building'],
#     'childcare': ['childcare_facility', 'day_care'],
#     'preschool': [],
#     'kindergarten': [],
#     'school': ['high_school', 'music_school', 'classroom'],
#     'library': ['university_library'],
#     'university': [],
#     'education': ['academic', 'academic_building', 'student_center']},
#    'health': {'clinic': [],
#     'dentist': ['dentist_office'],
#     'doctor': ['doctor'],
#     'hospital': [],
#     'pharmacy': [],
#     'health_center': [],
#     'nursing_home': [],
#     'medical': [],
#     'health': ['healthcare'],
#     'mental_health_clinic': []},
#    'religion': {'religion': ['christian',
#      'christian_anglican',
#      'christian_catholic',
#      'christian_evangelical',
#      'christian_lutheran',
#      'christian_methodist',
#      'christian_orthodox',
#      'christian_protestant',
#      'hindu',
#      'jewish',
#      'muslim',
#      'muslim_shia',
#      'muslim_sunni',
#      'sikh',
#      'taoist',
#      'cathedral',
#      'chapel',
#      'church',
#      'monastery',
#      'mosque',
#      'buddhist',
#      'presbytery',
#      'religiou',
#      'fraturnity',
#      'presbyterian\n']},
#    'transportation': {'transportation': [],
#     'airport': ['airfield', 'helipad', 'apron'],
#     'bus_station': ['bus_stop'],
#     'train_station': ['railway_station',
#      'railway_halt',
#      'tram_stop',
#      'subway_entrance'],
#     'car_rental': ['car_sharing'],
#     'taxi': ['taxi_rank'],
#     'ferry_terminal': [],
#     'fuel': ['service', 'gas_station'],
#     'parking': ['garage',
#      'parking_multistorey',
#      'parking_underground',
#      'vending_parking',
#      'parking_site',
#      'parking_lot',
#      'car_park',
#      'parking_structure',
#      'parking_space'],
#     'parking_bicycle': []},
#    'finance': {'bank': ['credit_union'], 'atm': [], 'insurance': []},
#    'other': {'government': ['courthouse',
#      'embassy',
#      'municipal',
#      'town_hall',
#      'city_hall',
#      'municipial'],
#     'police': ['police_station'],
#     'post_office': ['post_box', 'us_post_office'],
#     'community_centre': ['community_center'],
#     'fire_station': ['fire_department'],
#     'prison': ['jail_house', 'jail'],
#     'telephone': [],
#     'public_building': []}},
#   'commercial': {'leisure': {'cinema': [],
#     'bar': ['pub', 'nightclub'],
#     'aquarium': [],
#     'theatre': ['theater', 'concert_hall', 'outdoor_stage', 'auditorium'],
#     'theme_park': [],
#     'zoo': [],
#     'museum': ['arts_centre', 'arts_center', 'art_building'],
#     'casino': []},
#    'shopping': {'kiosk': ['newsagent',
#      'vending_machine',
#      'vending_cigarette',
#      'vending_any'],
#     'shop': ['clothe',
#      'shoe_shop',
#      'outdoor_shop',
#      'bicycle_shop',
#      'bookshop',
#      'car_dealership',
#      'computer_shop',
#      'furniture_shop',
#      'gift_shop',
#      'jeweller',
#      'mobile_phone_shop',
#      'sports_shop',
#      'stationery',
#      'toy_shop',
#      'video_shop',
#      'store',
#      'retail',
#      'optician',
#      'garden_centre',
#      'general',
#      'florist',
#      'chemist',
#      'retail_store',
#      'shopping',
#      'jeweler\n'],
#     'supermarket': ['butcher',
#      'convenience',
#      'greengrocer',
#      'grocery_store',
#      'grocery'],
#     'mall': ['department_store', 'market_place', 'shopping_center', 'market']},
#    'food': {'beverage': ['biergarten'],
#     'deli': [],
#     'restaurant': ['food_court'],
#     'cafe': ['coffee_shop', 'cafeteria'],
#     'bakery': [],
#     'fast_food': [],
#     'dining_hall': [],
#     'food': ['food_and_drink']},
#    'lifestyle': {'laundry': ['laundromat'],
#     'beauty_shop': ['hairdresser'],
#     'car_wash': ['car_repair'],
#     'hotel': ['hostel',
#      'motel',
#      'bed_and_breakfast',
#      'guesthouse',
#      'chalet',
#      'inn'],
#     'recycling': ['recycling_clothe',
#      'recycling_glas',
#      'recycling_metal',
#      'recycling_paper'],
#     'stadium': [],
#     'veterinary': [],
#     'travel_agent': [],
#     'self_storage': ['storage_unit',
#      'storage_facility',
#      'self-storage',
#      'storage',
#      'storage_building',
#      'storage_rental']},
#    'other': {'commercial': []}},
#   'busines': {'busines': {'industrial': [],
#     'office': [],
#     'company': ['verizon_building'],
#     'factory': ['quarry',
#      'power_station',
#      'manufacture',
#      'manufacturing',
#      'brewery',
#      'power_plant'],
#     'convention_center': ['convention_centre', 'conference_center']}},
#   'recreational': {'indoor': {'sports_centre': ['sports_house',
#      'sports_complex',
#      'sports_hall',
#      'recreational_center',
#      'gymnasium',
#      'gym',
#      'recreation_center',
#      'sport'],
#     'swimming_pool': []},
#    'outdoor': {'nature': ['beach',
#      'cave_entrance',
#      'cliff',
#      'glacier',
#      'peak',
#      'spring',
#      'tree',
#      'volcano',
#      'nature_reserve',
#      'forest',
#      'meadow',
#      'orchard',
#      'vineyard',
#      'scrub',
#      'gras',
#      'national_park',
#      'basin'],
#     'water': ['waterfall', 'reservoir', 'river', 'dock', 'glacier', 'wetland'],
#     'park': ['allotment',
#      'recreation_ground',
#      'village_green',
#      'garden',
#      'nursery',
#      'plant_nursery',
#      'arboretum'],
#     'farm': ['farmland', 'farmyard'],
#     'bicycle_rental': [],
#     'golf_course': [],
#     'dog_park': [],
#     'ice_rink': ['ice_skating_rink', 'skating_rink'],
#     'picnic_site': [],
#     'pitch': [],
#     'playground': [],
#     'track': [],
#     'viewpoint': ['observation_tower'],
#     'attraction': ['monument',
#      'memorial',
#      'castle',
#      'ruin',
#      'archaeological',
#      'battlefield',
#      'fort',
#      'aerialway_station'],
#     'hunting_stand': [],
#     'graveyard': ['cemetery'],
#     'tennis_court': [],
#     'shelter': ['alpine_hut'],
#     'camp_site': ['caravan_site'],
#     'tourism': ['tourist_info',
#      'tourist_map',
#      'tourist_board',
#      'tourist_guidepost'],
#     'country_club': []}}}}

# %% [markdown]
# ### 3. Extract and store Geofabrik data based on label map

# %%
layers = ["buildings", "landuse", "natural", "places", "pofw", "pois", "railways", "roads", "traffic", "transport", "water", "waterways"]

# %%
# def extract_data_for_label(labels, lvl3_path, category):
#     if category == "point":
#         suffix = "_free_*.shp"
#         filename_suffix = "_point"
#     elif category == "polygon":
#         suffix = "_a_free_*.shp"
#         filename_suffix = "_polygon"
#     else:
#         print("wrong type of file requested")
#         return
    
#     layer_df = pd.DataFrame()
#     for layer in layers:
#         for state in state_list:
#             state_folder_path = os.path.join(unzipped_folder_path, state)
#             state_shapefile_path = os.path.join(state_folder_path, "gis_osm_" + layer + suffix)
#             shapefile_finding_list = list(glob(state_shapefile_path))
#             if len(shapefile_finding_list) > 1:
#                 print("{} shapefiles found for {} for state {}".format(len(shapefile_finding_list), labels, state))

#             for p_shapefile in shapefile_finding_list:
#                 shpfile_df = gpd.read_file(p_shapefile)
#                 column_to_check = ["fclass", "type"]
#                 column_to_check = list(set(shpfile_df.columns).intersection(column_to_check))

                
#                 for label in labels:
#                     for colname in column_to_check:
#                         shpfile_df_label = shpfile_df[shpfile_df[colname] == label]
#                         layer_df = layer_df.append(shpfile_df_label)

#     # save extraction to shapefile
#     if layer_df.shape[0] > 0:
#         layer_df.to_file(lvl3_path + os.sep + labels[0] + filename_suffix + ".shp")
#     else:
#         print("                  No {} file found for {}".format(category, labels[0]))

# # extract function
# def organize_data_for_label(lvl3_label, label_map_lvl2, lvl3_path):
#     synonyms = label_map_lvl2[lvl3_label]
#     labels = [x for x in synonyms]
#     labels.insert(0, lvl3_label)
#     # point
#     extract_data_for_label(labels, lvl3_path, "point")
#     # polygon
#     extract_data_for_label(labels, lvl3_path, "polygon")

# # extract pipeline
# label_map = map_dict['map']
# create_folder(organized_data_folder_path)
# for lvl1_label in label_map: # from top level to bottom level
#     print("Level 1 : "+lvl1_label)
#     lvl1_path = organized_data_folder_path + os.sep + lvl1_label
#     create_folder(lvl1_path)
#     for lvl2_label in label_map[lvl1_label]:
#         print("  Level 2 : "+lvl2_label)
#         lvl2_path = lvl1_path + os.sep + lvl2_label
#         create_folder(lvl2_path)
#         for lvl3_label in label_map[lvl1_label][lvl2_label]:
#             print("    Level 3 : "+lvl3_label)
#             lvl3_path = lvl2_path + os.sep + lvl3_label
#             if not update:
#                 if len(os.listdir(path)) > 0:
#                     continue
#             create_folder(lvl3_path)
#             organize_data_for_label(lvl3_label, label_map[lvl1_label][lvl2_label], lvl3_path)

# %%
# extract 
# state - point/polygon - layer - label

# %%
def clean_tag_column(tag_series):
    
    cleaned_series = tag_series.str.lower()
    cleaned_series = cleaned_series.str.replace(" ", "_", case = False)
    cleaned_series = pd.Series([x[:-1] if x.endswith('s') else x for x in cleaned_series])
    
    return cleaned_series

# %%
def extract_all_landmarks_from_shapefile(label_map, organized_data_folder_path, shpfile_df_single_tag, shpfile_df_multi_tag, column_to_check, state, category, layer, shpfile_num):
    included_num = 0
    for lvl1_label in label_map: # from top level to bottom level
    #     print("Level 1 : "+lvl1_label)
        lvl1_path = organized_data_folder_path + os.sep + lvl1_label
        create_folder(lvl1_path)
        for lvl2_label in label_map[lvl1_label]:
    #         print("  Level 2 : "+lvl2_label)
            lvl2_path = lvl1_path + os.sep + lvl2_label
            label_map_lvl2 = label_map[lvl1_label][lvl2_label]
            create_folder(lvl2_path)
            for lvl3_label in label_map[lvl1_label][lvl2_label]:
    #             print("    Level 3 : "+lvl3_label)
                lvl3_path = lvl2_path + os.sep + lvl3_label
                lvl3_file_name = "_".join([lvl3_label, state, layer, shpfile_num, category+".shp"])
                lvl3_file_path = os.path.join(lvl3_path, lvl3_file_name)
                if not update:
                    if os.path.exists(lvl3_file_path):
                        continue
                create_folder(lvl3_path)
                synonyms = label_map_lvl2[lvl3_label]
                labels = [x for x in synonyms]
                labels.insert(0, lvl3_label)

                df_label = pd.DataFrame()
                for label in labels:
                    shpfile_df_single_tag_label = shpfile_df_single_tag[shpfile_df_single_tag[column_to_check] == label]
                    shpfile_df_multi_tag_label = shpfile_df_multi_tag[shpfile_df_multi_tag[column_to_check].str.contains(label)]
                    df_label = df_label.append(shpfile_df_single_tag_label)
                    df_label = df_label.append(shpfile_df_multi_tag_label)

                # save extraction to shapefile
                if df_label.shape[0] > 0:
                    df_label.to_file(lvl3_file_path)
                    included_num += df_label.shape[0]
    return included_num

# %%
start = time.time()

#
label_map = map_dict['map']
create_folder(organized_data_folder_path)

#
label_count_dict = dict()
for layer in layers:
    label_count_dict[layer] = {"none": 0, "labeled": 0, "included": 0}

#
start = 0
for state in state_list:
    print(state)
    if state == "new jersey":
        start = 1
    if start == 0:
        continue
    start_state = time.time()
    state_folder_path = os.path.join(unzipped_folder_path, state)
    for category in ["point", "polygon"]:
        print("  "+category)
        if category == "point":
            suffix = "_free_*.shp"
            filename_suffix = "_point"
        elif category == "polygon":
            suffix = "_a_free_*.shp"
            filename_suffix = "_polygon"
        else:
            pass
        
        for layer in layers:          
            print("    "+layer)
            shapefile_pattern = os.path.join(state_folder_path, "gis_osm_" + layer + suffix)
            shapefile_finding_list = list(glob(shapefile_pattern))
            if len(shapefile_finding_list) > 1:
                print("{} shapefiles found for {} for state {}".format(len(shapefile_finding_list), labels, state))

            for p_shapefile in shapefile_finding_list:
                shpfile_df = gpd.read_file(p_shapefile)
                label_count_dict[layer]["none"] += shpfile_df.shape[0]
                column_to_check = ["fclass", "type"]
                column_to_check = list(set(shpfile_df.columns).intersection(column_to_check))
                if len(column_to_check) > 1:
                    if len(shpfile_df['fclass'].unique()) > len(shpfile_df['type'].unique()):
                        column_to_check = "fclass"
                    else:
                        column_to_check = "type"
                else:
                    column_to_check = column_to_check[0]
                print("      column to check : "+column_to_check)
#                 column_to_check = list(set(shpfile_df.columns).intersection(column_to_check))
                shpfile_num = p_shapefile.split("_free_")[1].strip(".shp")
    
                # clean label columns: lower case, replace space with underscore, remove ending s, split by ";"
                shpfile_df["tag_col_type"] = ["none" if x is None else "str" for x in shpfile_df[column_to_check]]
                shpfile_df = shpfile_df[shpfile_df["tag_col_type"]!="none"]
                label_count_dict[layer]["labeled"] += shpfile_df.shape[0]
                shpfile_df.reset_index(inplace=True, drop=True)
                shpfile_df[column_to_check] = clean_tag_column(shpfile_df[column_to_check])
                shpfile_df[column_to_check] = shpfile_df[column_to_check].astype(str)
                shpfile_df_single_tag = shpfile_df[~shpfile_df[column_to_check].str.contains(";")]
                shpfile_df_single_tag.reset_index(inplace=True, drop=True)
                shpfile_df_multi_tag = shpfile_df[shpfile_df[column_to_check].str.contains(";")]
                shpfile_df_multi_tag.reset_index(inplace=True, drop=True)
                
                included_num = extract_all_landmarks_from_shapefile(label_map, organized_data_folder_path, shpfile_df_single_tag, shpfile_df_multi_tag, column_to_check, state, category, layer, shpfile_num)
                label_count_dict[layer]["included"] += included_num
    end = time.time()
    print(f"Runtime for {state} is {end - start_state}")
                
end = time.time()
print(f"Total runtime of the program is {end - start}")
# Out:
# alabama
# alaska
# arizona
# arkansas
# norcal
# socal
# colorado
# connecticut
# delaware
# district of columbia
# florida
# georgia
# hawaii
# idaho
# illinois
# indiana
# iowa
# kansas
# kentucky
# louisiana
# maine
# maryland
# massachusetts
# michigan
# minnesota
# mississippi
# missouri
# montana
# nebraska
# nevada
# new hampshire
# new jersey
#   point
#     buildings
#     landuse
#     natural
#       column to check : fclass
#     places
#       column to check : fclass
#     pofw
#       column to check : fclass
#     pois
#       column to check : fclass
#     railways
#       column to check : fclass
#     roads
#       column to check : fclass
#     traffic
#       column to check : fclass
#     transport
#       column to check : fclass
#     water
#     waterways
#       column to check : fclass
#   polygon
#     buildings
#       column to check : type
#     landuse
#       column to check : fclass
#     natural
#       column to check : fclass
#     places
#       column to check : fclass
#     pofw
#       column to check : fclass
#     pois
#       column to check : fclass
#     railways
#     roads
#     traffic
#       column to check : fclass
#     transport
#       column to check : fclass
#     water
#       column to check : fclass
#     waterways
# Runtime for new jersey is 492.07018065452576
# new mexico
#   point
#     buildings
#     landuse
#     natural
#       column to check : fclass
#     places
#       column to check : fclass
#     pofw
#       column to check : fclass
#     pois
#       column to check : fclass
#     railways
#       column to check : fclass
#     roads
#       column to check : fclass
#     traffic
#       column to check : fclass
#     transport
#       column to check : fclass
#     water
#     waterways
#       column to check : fclass
#   polygon
#     buildings
#       column to check : type
#     landuse
#       column to check : fclass
#     natural
#       column to check : fclass
#     places
#       column to check : fclass
#     pofw
#       column to check : fclass
#     pois
#       column to check : fclass
#     railways
#     roads
#     traffic
#       column to check : fclass
#     transport
#       column to check : fclass
#     water
#       column to check : fclass
#     waterways
# Runtime for new mexico is 301.7166543006897
# new york
#   point
#     buildings
#     landuse
#     natural
#       column to check : fclass
#     places
#       column to check : fclass
#     pofw
#       column to check : fclass
#     pois
#       column to check : fclass
#     railways
#       column to check : fclass
#     roads
#       column to check : fclass
#     traffic
#       column to check : fclass
#     transport
#       column to check : fclass
#     water
#     waterways
#       column to check : fclass
#   polygon
#     buildings
#       column to check : type
#     landuse
#       column to check : fclass
#     natural
#       column to check : fclass
#     places
#       column to check : fclass
#     pofw
#       column to check : fclass
#     pois
#       column to check : fclass
#     railways
#     roads
#     traffic
#       column to check : fclass
#     transport
#       column to check : fclass
#     water
#       column to check : fclass
#     waterways
# Runtime for new york is 1217.6142904758453
# north carolina
#   point
#     buildings
#     landuse
#     natural
#       column to check : fclass
#     places
#       column to check : fclass
#     pofw
#       column to check : fclass
#     pois
#       column to check : fclass
#     railways
#       column to check : fclass
#     roads
#       column to check : fclass
#     traffic
#       column to check : fclass
#     transport
#       column to check : fclass
#     water
#     waterways
#       column to check : fclass
#   polygon
#     buildings
#       column to check : type
#     landuse
#       column to check : fclass
#     natural
#       column to check : fclass
#     places
#       column to check : fclass
#     pofw
#       column to check : fclass
#     pois
#       column to check : fclass
#     railways
#     roads
#     traffic
#       column to check : fclass
#     transport
#       column to check : fclass
#     water
#       column to check : fclass
#     waterways
# Runtime for north carolina is 1074.1261229515076
# north dakota
#   point
#     buildings
#     landuse
#     natural
#       column to check : fclass
#     places
#       column to check : fclass
#     pofw
#       column to check : fclass
#     pois
#       column to check : fclass
#     railways
#       column to check : fclass
#     roads
#       column to check : fclass
#     traffic
#       column to check : fclass
#     transport
#       column to check : fclass
#     water
#     waterways
#       column to check : fclass
#   polygon
#     buildings
#       column to check : type
#     landuse
#       column to check : fclass
#     natural
#       column to check : fclass
#     places
#       column to check : fclass
#     pofw
#       column to check : fclass
#     pois
#       column to check : fclass
#     railways
#     roads
#     traffic
#       column to check : fclass
#     transport
#       column to check : fclass
#     water
#       column to check : fclass
#     waterways
# Runtime for north dakota is 293.06696105003357
# ohio
#   point
#     buildings
#     landuse
#     natural
#       column to check : fclass
#     places
#       column to check : fclass
#     pofw
#       column to check : fclass
#     pois
#       column to check : fclass
#     railways
#       column to check : fclass
#     roads
#       column to check : fclass
#     traffic
#       column to check : fclass
#     transport
#       column to check : fclass
#     water
#     waterways
#       column to check : fclass
#   polygon
#     buildings
#       column to check : type
#     landuse
#       column to check : fclass
#     natural
#       column to check : fclass
#     places
#       column to check : fclass
#     pofw
#       column to check : fclass
#     pois
#       column to check : fclass
#     railways
#     roads
#     traffic
#       column to check : fclass
#     transport
#       column to check : fclass
#     water
#       column to check : fclass
#     waterways
# Runtime for ohio is 711.5988037586212
# oklahoma
#   point
#     buildings
#     landuse
#     natural
#       column to check : fclass
#     places
#       column to check : fclass
#     pofw
#       column to check : fclass
#     pois
#       column to check : fclass
#     railways
#       column to check : fclass
#     roads
#       column to check : fclass
#     traffic
#       column to check : fclass
#     transport
#       column to check : fclass
#     water
#     waterways
#       column to check : fclass
#   polygon
#     buildings
#       column to check : type
#     landuse
#       column to check : fclass
#     natural
#       column to check : fclass
#     places
#       column to check : fclass
#     pofw
#       column to check : fclass
#     pois
#       column to check : fclass
#     railways
#     roads
#     traffic
#       column to check : fclass
#     transport
#       column to check : fclass
#     water
#       column to check : fclass
#     waterways
# Runtime for oklahoma is 424.9534420967102
# oregon
#   point
#     buildings
#     landuse
#     natural
#       column to check : fclass
#     places
#       column to check : fclass
#     pofw
#       column to check : fclass
#     pois
#       column to check : fclass
#     railways
#       column to check : fclass
#     roads
#       column to check : fclass
#     traffic
#       column to check : fclass
#     transport
#       column to check : fclass
#     water
#     waterways
#       column to check : fclass
#   polygon
#     buildings
#       column to check : type
#     landuse
#       column to check : fclass
#     natural
#       column to check : fclass
#     places
#       column to check : fclass
#     pofw
#       column to check : fclass
#     pois
#       column to check : fclass
#     railways
#     roads
#     traffic
#       column to check : fclass
#     transport
#       column to check : fclass
#     water
#       column to check : fclass
#     waterways
# Runtime for oregon is 370.98840284347534
# pennsylvania
#   point
#     buildings
#     landuse
#     natural
#       column to check : fclass
#     places
#       column to check : fclass
#     pofw
#       column to check : fclass
#     pois
#       column to check : fclass
#     railways
#       column to check : fclass
#     roads
#       column to check : fclass
#     traffic
#       column to check : fclass
#     transport
#       column to check : fclass
#     water
#     waterways
#       column to check : fclass
#   polygon
#     buildings
#       column to check : type
#     landuse
#       column to check : fclass
#     natural
#       column to check : fclass
#     places
#       column to check : fclass
#     pofw
#       column to check : fclass
#     pois
#       column to check : fclass
#     railways
#     roads
#     traffic
#       column to check : fclass
#     transport
#       column to check : fclass
#     water
#       column to check : fclass
#     waterways
# Runtime for pennsylvania is 529.343502998352
# puerto rico
#   point
#     buildings
#     landuse
#     natural
#       column to check : fclass
#     places
#       column to check : fclass
#     pofw
#       column to check : fclass
#     pois
#       column to check : fclass
#     railways
#       column to check : fclass
#     roads
#       column to check : fclass
#     traffic
#       column to check : fclass
#     transport
#       column to check : fclass
#     water
#     waterways
#       column to check : fclass
#   polygon
#     buildings
#       column to check : type
#     landuse
#       column to check : fclass
#     natural
#       column to check : fclass
#     places
#       column to check : fclass
#     pofw
#       column to check : fclass
#     pois
#       column to check : fclass
#     railways
#     roads
#     traffic
#       column to check : fclass
#     transport
#       column to check : fclass
#     water
#       column to check : fclass
#     waterways
# Runtime for puerto rico is 250.72412371635437
# rhode island
#   point
#     buildings
#     landuse
#     natural
#       column to check : fclass
#     places
#       column to check : fclass
#     pofw
#       column to check : fclass
#     pois
#       column to check : fclass
#     railways
#       column to check : fclass
#     roads
#       column to check : fclass
#     traffic
#       column to check : fclass
#     transport
#       column to check : fclass
#     water
#     waterways
#       column to check : fclass
#   polygon
#     buildings
#       column to check : type
#     landuse
#       column to check : fclass
#     natural
#       column to check : fclass
#     places
#       column to check : fclass
#     pofw
#       column to check : fclass
#     pois
#       column to check : fclass
#     railways
#     roads
#     traffic
#       column to check : fclass
#     transport
#       column to check : fclass
#     water
#       column to check : fclass
#     waterways
# Runtime for rhode island is 121.26187753677368
# south carolina
#   point
#     buildings
#     landuse
#     natural
#       column to check : fclass
#     places
#       column to check : fclass
#     pofw
#       column to check : fclass
#     pois
#       column to check : fclass
#     railways
#       column to check : fclass
#     roads
#       column to check : fclass
#     traffic
#       column to check : fclass
#     transport
#       column to check : fclass
#     water
#     waterways
#       column to check : fclass
#   polygon
#     buildings
#       column to check : type
#     landuse
#       column to check : fclass
#     natural
#       column to check : fclass
#     places
#       column to check : fclass
#     pofw
#       column to check : fclass
#     pois
#       column to check : fclass
#     railways
#     roads
#     traffic
#       column to check : fclass
#     transport
#       column to check : fclass
#     water
#       column to check : fclass
#     waterways
# Runtime for south carolina is 293.464884519577
# south dakota
#   point
#     buildings
#     landuse
#     natural
#       column to check : fclass
#     places
#       column to check : fclass
#     pofw
#       column to check : fclass
#     pois
#       column to check : fclass
#     railways
#       column to check : fclass
#     roads
#       column to check : fclass
#     traffic
#       column to check : fclass
#     transport
#       column to check : fclass
#     water
#     waterways
#       column to check : fclass
#   polygon
#     buildings
#       column to check : type
#     landuse
#       column to check : fclass
#     natural
#       column to check : fclass
#     places
#       column to check : fclass
#     pofw
#       column to check : fclass
#     pois
#       column to check : fclass
#     railways
#     roads
#     traffic
#       column to check : fclass
#     transport
#       column to check : fclass
#     water
#       column to check : fclass
#     waterways
# Runtime for south dakota is 130.52809596061707
# tennessee
#   point
#     buildings
#     landuse
#     natural
#       column to check : fclass
#     places
#       column to check : fclass
#     pofw
#       column to check : fclass
#     pois
#       column to check : fclass
#     railways
#       column to check : fclass
#     roads
#       column to check : fclass
#     traffic
#       column to check : fclass
#     transport
#       column to check : fclass
#     water
#     waterways
#       column to check : fclass
#   polygon
#     buildings
#       column to check : type
#     landuse
#       column to check : fclass
#     natural
#       column to check : fclass
#     places
#       column to check : fclass
#     pofw
#       column to check : fclass
#     pois
#       column to check : fclass
#     railways
#     roads
#     traffic
#       column to check : fclass
#     transport
#       column to check : fclass
#     water
#       column to check : fclass
#     waterways
# Runtime for tennessee is 328.9694125652313
# texas
#   point
#     buildings
#     landuse
#     natural
#       column to check : fclass
#     places
#       column to check : fclass
#     pofw
#       column to check : fclass
#     pois
#       column to check : fclass
#     railways
#       column to check : fclass
#     roads
#       column to check : fclass
#     traffic
#       column to check : fclass
#     transport
#       column to check : fclass
#     water
#     waterways
#       column to check : fclass
#   polygon
#     buildings
#       column to check : type
#     landuse
#       column to check : fclass
#     natural
#       column to check : fclass
#     places
#       column to check : fclass
#     pofw
#       column to check : fclass
#     pois
#       column to check : fclass
#     railways
#     roads
#     traffic
#       column to check : fclass
#     transport
#       column to check : fclass
#     water
#       column to check : fclass
#     waterways
# Runtime for texas is 1141.8659658432007
# united states virgin islands
#   point
#     buildings
#     landuse
#     natural
#       column to check : fclass
#     places
#       column to check : fclass
#     pofw
#       column to check : fclass
#     pois
#       column to check : fclass
#     railways
#       column to check : fclass
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   """
#     roads
#       column to check : fclass
#     traffic
#       column to check : fclass
#     transport
#       column to check : fclass
#     water
#     waterways
#       column to check : fclass
#   polygon
#     buildings
#       column to check : type
#     landuse
#       column to check : fclass
#     natural
#       column to check : fclass
#     places
#       column to check : fclass
#     pofw
#       column to check : fclass
#     pois
#       column to check : fclass
#     railways
#     roads
#     traffic
#       column to check : fclass
#     transport
#       column to check : fclass
#     water
#       column to check : fclass
#     waterways
# Runtime for united states virgin islands is 100.48437261581421
# utah
#   point
#     buildings
#     landuse
#     natural
#       column to check : fclass
#     places
#       column to check : fclass
#     pofw
#       column to check : fclass
#     pois
#       column to check : fclass
#     railways
#       column to check : fclass
#     roads
#       column to check : fclass
#     traffic
#       column to check : fclass
#     transport
#       column to check : fclass
#     water
#     waterways
#       column to check : fclass
#   polygon
#     buildings
#       column to check : type
#     landuse
#       column to check : fclass
#     natural
#       column to check : fclass
#     places
#       column to check : fclass
#     pofw
#       column to check : fclass
#     pois
#       column to check : fclass
#     railways
#     roads
#     traffic
#       column to check : fclass
#     transport
#       column to check : fclass
#     water
#       column to check : fclass
#     waterways
# Runtime for utah is 221.36469173431396
# vermont
#   point
#     buildings
#     landuse
#     natural
#       column to check : fclass
#     places
#       column to check : fclass
#     pofw
#       column to check : fclass
#     pois
#       column to check : fclass
#     railways
#       column to check : fclass
#     roads
#       column to check : fclass
#     traffic
#       column to check : fclass
#     transport
#       column to check : fclass
#     water
#     waterways
#       column to check : fclass
#   polygon
#     buildings
#       column to check : type
#     landuse
#       column to check : fclass
#     natural
#       column to check : fclass
#     places
#       column to check : fclass
#     pofw
#       column to check : fclass
#     pois
#       column to check : fclass
#     railways
#     roads
#     traffic
#       column to check : fclass
#     transport
#       column to check : fclass
#     water
#       column to check : fclass
#     waterways
# Runtime for vermont is 106.77984356880188
# virginia
#   point
#     buildings
#     landuse
#     natural
#       column to check : fclass
#     places
#       column to check : fclass
#     pofw
#       column to check : fclass
#     pois
#       column to check : fclass
#     railways
#       column to check : fclass
#     roads
#       column to check : fclass
#     traffic
#       column to check : fclass
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#     transport
#       column to check : fclass
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#     water
#     waterways
#       column to check : fclass
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   polygon
#     buildings
#       column to check : type
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#     landuse
#       column to check : fclass
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#     natural
#       column to check : fclass
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#     places
#       column to check : fclass
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#     pofw
#       column to check : fclass
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#     pois
#       column to check : fclass
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#     railways
#     roads
#     traffic
#       column to check : fclass
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#     transport
#       column to check : fclass
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#     water
#       column to check : fclass
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#     waterways
# Runtime for virginia is 1029.96879696846
# washington
#   point
#     buildings
#     landuse
#     natural
#       column to check : fclass
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#     places
#       column to check : fclass
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#     pofw
#       column to check : fclass
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#     pois
#       column to check : fclass
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# ...
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#     landuse
#       column to check : fclass
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#     natural
#       column to check : fclass
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#     places
#       column to check : fclass
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#     pofw
#       column to check : fclass
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#     pois
#       column to check : fclass
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#     railways
#     roads
#     traffic
#       column to check : fclass
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#     transport
#       column to check : fclass
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#     water
#       column to check : fclass
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# /home/li.jix/pyenvs/TIME/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#     waterways
# Runtime for wyoming is 244.98759746551514
# Total runtime of the program is 1655483844.0750072

# %%
map_file_path = os.path.abspath(os.path.join(geo_map_path, os.pardir))

label_count_path = os.path.join(map_file_path, "label_count_dict.json")

with open(label_count_path, 'w') as fp:
    json.dump(label_count_dict, fp)

# %%
10311.742320775986/60/60
# Out:
# 2.8643728668822184

# %%
label_count_dict
# Out:
# {'buildings': {'none': 48435833, 'labeled': 16283105, 'included': 14588810},
#  'landuse': {'none': 3344978, 'labeled': 3344978, 'included': 3331698},
#  'natural': {'none': 2056612, 'labeled': 2056612, 'included': 2062302},
#  'places': {'none': 205101, 'labeled': 205101, 'included': 487},
#  'pofw': {'none': 235513, 'labeled': 235513, 'included': 235513},
#  'pois': {'none': 2807137, 'labeled': 2807137, 'included': 2467828},
#  'railways': {'none': 387139, 'labeled': 387139, 'included': 0},
#  'roads': {'none': 37063787, 'labeled': 37063787, 'included': 28891427},
#  'traffic': {'none': 5214066, 'labeled': 5214066, 'included': 1031160},
#  'transport': {'none': 270918, 'labeled': 270918, 'included': 270918},
#  'water': {'none': 2179499, 'labeled': 2179499, 'included': 2147549},
#  'waterways': {'none': 4614306, 'labeled': 4614306, 'included': 283435}}

# %%
print("included/labeled")
for layer in label_count_dict:
    print(f"  {layer} : {round(label_count_dict[layer]['included']/label_count_dict[layer]['labeled'],3)}")
# Out:
# included/labeled
#   buildings : 0.896
#   landuse : 0.996
#   natural : 1.003
#   places : 0.002
#   pofw : 1.0
#   pois : 0.879
#   railways : 0.0
#   roads : 0.78
#   traffic : 0.198
#   transport : 1.0
#   water : 0.985
#   waterways : 0.061

# %% [markdown]
# ### 4. New unclassified labels

# %%
old_list = set(map_dict['unique_list'])

# %%
start = time.time()
new_list = set()

for state in state_list:
    print(state)
    state_folder_path = os.path.join(unzipped_folder_path, state)
    state_shapefile_path = os.path.join(state_folder_path, "gis_osm_*.shp")
    shapefile_finding_list = list(glob(state_shapefile_path))

    for p_shapefile in shapefile_finding_list:
        shpfile_df = gpd.read_file(p_shapefile)
        column_to_check = ["fclass", "type"]
        column_to_check = list(set(shpfile_df.columns).intersection(column_to_check))
        for colname in column_to_check:
            new_labels = set(shpfile_df[colname].unique())
            new_list = new_list.union(new_labels)
            
end = time.time()
print(f"Runtime of the program is {end - start}")
# Out:
# alabama
# alaska
# arizona
# arkansas
# norcal
# socal
# colorado
# connecticut
# delaware
# district of columbia
# florida
# georgia
# hawaii
# idaho
# illinois
# indiana
# iowa
# kansas
# kentucky
# louisiana
# maine
# maryland
# massachusetts
# michigan
# minnesota
# mississippi
# missouri
# montana
# nebraska
# nevada
# new hampshire
# new jersey
# new mexico
# new york
# north carolina
# north dakota
# ohio
# oklahoma
# oregon
# pennsylvania
# puerto rico
# rhode island
# south carolina
# south dakota
# tennessee
# texas
# united states virgin islands
# utah
# vermont
# virginia
# washington
# west virginia
# wisconsin
# wyoming
# Runtime of the program is 3437.8917973041534

# %%
new_list - old_list
# Out:
# {'mixed-use',
#  'rebuilt',
#  'roof_overhang',
#  'cowshed',
#  'stable',
#  'new',
#  'tomb',
#  'workshop',
#  'inside_store',
#  'public;government',
#  'mobile',
#  'suite',
#  'indzustrial',
#  'Drive_Through',
#  'boat storage house',
#  'apartments (2nd floo',
#  'tower 2',
#  'garages;yes',
#  'yurt',
#  'undefined',
#  'camera_surveillance',
#  'fourplex',
#  'resturant',
#  'g',
#  'fidelity',
#  'Cafeteria',
#  'Tractor supply',
#  'private',
#  'housev',
#  'barn;commercial',
#  'column',
#  'Morse TH',
#  'Pierce_County_Buildi',
#  'cabinet',
#  'house;detached',
#  'data',
#  'ski lodge',
#  'fire department',
#  'apartments',
#  'carps',
#  'public_building;yes',
#  'mixed_use',
#  'booth',
#  'tribune',
#  'Station',
#  'Composting_System',
#  'Carriage Lane',
#  'sg',
#  'Livestock_Barn',
#  'apartments;garage',
#  'open_air',
#  'barrack',
#  'clubhouse',
#  'yes;university',
#  'shrine',
#  'stilt house',
#  'retirement home',
#  'narrow_gauge',
#  'caboose',
#  'House',
#  'doghouse',
#  'tes',
#  'boat_house',
#  'historical',
#  'substation',
#  'restroom',
#  'Meat_Locker',
#  'occupied',
#  'warehouse/offices',
#  'Iona_College_Dorm',
#  'shed;retail',
#  'county',
#  'guardhouse',
#  'cloister',
#  'antique auto repair',
#  'roo',
#  'Commercial,_House_of',
#  'farmq',
#  'roof;house',
#  'dog_house',
#  'Bank',
#  'Townhouse',
#  'Art_Building',
#  'Skating_Rink',
#  'build',
#  'yes;public',
#  'yert',
#  'Gymnasium',
#  'Hackerspace',
#  'p',
#  'cabin1',
#  'static_caravan;resid',
#  'pier',
#  'kingdom_hall',
#  'VFW',
#  'commercial;detached',
#  'campanile',
#  'Dump Station',
#  'static_mobile_home',
#  'derelict,_uninhabite',
#  'primary_link',
#  'Detached_Classroom',
#  'disused:church',
#  'Sumter Psychiatry As',
#  'Outdoor_Stage',
#  'Ice_Skating_Rink',
#  'commercial;office',
#  'tank',
#  'Yes,_College',
#  'Healthcare',
#  'manufactured',
#  'research',
#  'shed,_detached',
#  'R3 Environmental',
#  'chr',
#  'cage',
#  'Detached_hangar',
#  'Mail_box_shed',
#  'water treatment',
#  'indoor_swimming_pool',
#  'minor parts',
#  'yes_but_the_burgee_b',
#  'ros',
#  's3',
#  'unknown',
#  'gas station',
#  'pagoda',
#  'yes;hotel',
#  'tents',
#  'conservatory',
#  'function_hall',
#  'business/Kavanaugh C',
#  'Auditorium',
#  'ski jump',
#  'retail; yes',
#  'tabernacle',
#  'armory',
#  'computers',
#  'Ski_Jump',
#  'yes;commercial',
#  'disused:garage',
#  'townhall',
#  'hg',
#  'Spring Branch Home',
#  'roof;office',
#  'i',
#  'Restroom',
#  'garage;house',
#  'yes;parking',
#  'lighthouse',
#  'garage;shed',
#  'shelt',
#  None,
#  'Bayview South',
#  'gov',
#  'Classrooms',
#  'Religious',
#  'aprtments',
#  'plant',
#  'r',
#  'fraturnity',
#  'Zap_House',
#  'salt_pyramid',
#  'lib',
#  'apartment_office',
#  'Suite_212,_Waverly_P',
#  'parking lot',
#  'townhomes',
#  'crossing',
#  'social_facility',
#  'terr',
#  'Long_Beach_Public_Li',
#  'colocation',
#  'ranch',
#  'sile',
#  'residentialbuilding=',
#  'commercial; yes',
#  'marina',
#  'school;roof',
#  'clubhouse;gym',
#  'recreation',
#  'iy',
#  'o',
#  'ski_jump',
#  'natatorium',
#  'riverbank',
#  'renovation',
#  'house;garage',
#  'wayside_shrine',
#  'Medical',
#  'Museum',
#  'temple',
#  'Residential_Real_Est',
#  'Crayfish_Lab',
#  'Old_Wentworth_Elevat',
#  'bleacher',
#  'Building part',
#  'residential;commerci',
#  'commercial;retail',
#  'gazeebo',
#  'bridge;roof',
#  'fraternity house',
#  'club_house',
#  'hotel;yes',
#  'ret',
#  'razed',
#  'archaeological_site',
#  'weapon_armory',
#  'open',
#  'health_House',
#  'ho',
#  'Toilets',
#  'track_grade1',
#  'farm_building',
#  'Assisted_Living_Faci',
#  'parking;yes',
#  'University_Office_Bu',
#  'meeting_room',
#  'auxiliary',
#  'Campus_Library',
#  'school; roof; school',
#  'ys',
#  'pumping_station',
#  'Bradbury Place',
#  'historic',
#  'complete',
#  'barn;house',
#  "Wagner's",
#  'Arundel Public Works',
#  'recreation center',
#  'concession stand',
#  'house;static_caravan',
#  'residential,building',
#  'critical_infrastruct',
#  'townhome',
#  'trunk',
#  'HVAC',
#  'garage;apartments',
#  'office;industrial',
#  'romney',
#  'stands',
#  'outer',
#  'rocket',
#  'semi',
#  'yesshed',
#  'telescope',
#  'structure',
#  'Rec_Center',
#  'arena',
#  'garage;yes',
#  'unkown',
#  'Wolfe_5',
#  'doctors',
#  'prision',
#  'yes;carport',
#  'works',
#  'heritage_building',
#  'apartments;hotel',
#  'retail;shed;yes',
#  'arbor',
#  'island',
#  'floating_home',
#  'changing rooms',
#  'bathroom',
#  'Faster Care',
#  'amphitheatre',
#  'room',
#  'roof;industrial',
#  'woods',
#  'yes;government',
#  'Funeral Home',
#  'apartments;garages',
#  'boat',
#  'yes;cabin',
#  'rectory',
#  'entrance',
#  'gas_pumps_under_awni',
#  'country_club',
#  'portico',
#  'grandslam',
#  'outhouse',
#  'wall',
#  'cistern',
#  'Weymouth Housing Aut',
#  'bath_house',
#  'childcare facility',
#  'canopy',
#  'musuem',
#  'roof;hospital',
#  'television_station',
#  'carillon',
#  'cabana',
#  'yes,_Latrine',
#  'Engine_house',
#  'Workshop',
#  'neighborhood office',
#  'yer',
#  'bus',
#  'bus_shelter',
#  'platform',
#  'cargo_terminal',
#  'apartments;building:',
#  'stables',
#  'show_house',
#  'fire_station;governm',
#  'part',
#  'commercial_building',
#  'affordable housing',
#  'Physical Plant (PP)',
#  'roof;public',
#  'construction',
#  'Transportation_Broke',
#  'residential;roof',
#  'ger',
#  'commercial;service',
#  'pavillon',
#  'commercial;roof',
#  'Telescope_Dome',
#  'hot_shop',
#  'secondary_link',
#  'seats',
#  'Slaughter_House',
#  'mapillary',
#  'chapel;university',
#  'GA',
#  'Dining/Instructional',
#  'school;commercial',
#  'track_grade5',
#  'latrine',
#  'municipial',
#  'tech_cab',
#  'slipway',
#  'bunker',
#  'train',
#  'foundation/ruin',
#  'riverboat',
#  'retail;roof',
#  'sidewalk',
#  'station',
#  'Structure added, not',
#  'covered_area',
#  'apartments;residenti',
#  'walkway',
#  'Leonard',
#  'tree_house',
#  'dining_hall',
#  'path',
#  'Funeraria',
#  'burial_vault',
#  'hotel_building',
#  'tweak',
#  'skywalk',
#  'terrace',
#  'Some_kind_of_structu',
#  'dugout',
#  'Terminal A JetBlue P',
#  'Police Station',
#  'carousel',
#  'grocery store',
#  'city_hall',
#  'Chapel',
#  'Kennels',
#  'Laboratory_and_Class',
#  'barn;residential',
#  'bakehouse',
#  'tertiary',
#  'gazebo;roof',
#  'chuch',
#  'presbyterian',
#  'quonset hut',
#  'maintenence',
#  'storage_hall',
#  'house addr:city=Chul',
#  'terminal',
#  'Resturant',
#  'gatehouse',
#  'private_residence',
#  'retail;residential',
#  'Fraternity',
#  'business',
#  'FIXME: Unknown',
#  'grandstand',
#  'res',
#  'hipped',
#  's\\',
#  'porch',
#  'building',
#  'hall_of_residence',
#  'carport;yes',
#  'residentialQ',
#  'ticketing',
#  'industrial;yes',
#  'retail;shed',
#  'nails',
#  'shadehouse',
#  'medium',
#  'ywa',
#  'electricity',
#  'Kwick_Stop_Coin_Op_L',
#  'smokery',
#  'parking_shelter',
#  'lesiure',
#  'Group Housing',
#  'houes',
#  'railway_shed',
#  'commercial;education',
#  'masonic',
#  'salt_barn',
#  'recre',
#  'Insurance',
#  'yes;shed',
#  'open_exposure',
#  'Shopping Center',
#  'car',
#  'outdoor_structure',
#  'windmill',
#  'Chabad_House',
#  'yes#TexasTech',
#  'fire station',
#  'Bar,_Golfcourse',
#  'nuclear',
#  'Jeweler',
#  'Gate_House',
#  'college;yes',
#  'pharmaceutical_compa',
#  'furnace',
#  'cabin5',
#  'barn',
#  'h]',
#  'storageq',
#  'villa',
#  'Skyway',
#  'industrial;commercia',
#  'corridor',
#  'apartmenta',
#  'sheepfold',
#  'way',
#  'Cottage Front',
#  'townhouses',
#  'roof;church',
#  'maintenance',
#  'condominiums',
#  'house;roof',
#  'elevator',
#  'storage_unit',
#  'church;carport',
#  'shed;house',
#  'monorail',
#  'Residential_Condomin',
#  'empty',
#  'barm',
#  'non-profit',
#  'parish_hall',
#  'potato_barn',
#  'Granite Falls',
#  'living_street',
#  'hs',
#  'Salon',
#  'warehouse;yes',
#  'modular',
#  'yes;hospital',
#  'hr',
#  'chu',
#  'auditorium',
#  'hopsital',
#  'sleeper_car',
#  'gathering',
#  'Instructional',
#  'residential;retail',
#  'portable',
#  'gasometer',
#  'toll_booth',
#  'palapa',
#  'dormitory;university',
#  'YMCA',
#  'nonprofit_center',
#  'yard',
#  'gazeboo',
#  'Forum',
#  'generator',
#  'Jail_House',
#  'dormatory',
#  'School_Ground',
#  'rail_car',
#  'chimney',
#  'carpark',
#  'residential;house',
#  'Preschool',
#  'kennel',
#  'yb',
#  'gh',
#  'sty',
#  'pump_house',
#  'Event_Center',
#  'bri',
#  'toilets',
#  'rec_center',
#  'engine_house',
#  'Emergency Generator',
#  'flour_mill',
#  'Bunkhouse',
#  'refectory',
#  'residential_home_and',
#  'Mechanical_Room',
#  'razed building',
#  'public;yes',
#  'manor',
#  'proposed',
#  'damaged',
#  'Department_Building',
#  'out',
#  'dormitory;yes',
#  'university library',
#  'inner',
#  'attached',
#  'nursing facility',
#  'rental_office',
#  'RV',
#  'aba',
#  'amphitheater',
#  'commercial;governmen',
#  'residentialqIvan Agu',
#  'Car_Dealership',
#  'church;university',
#  'footway',
#  'US_Post_Office',
#  'Jerry Siegel Lane',
#  'Mechanical_room',
#  'watermill',
#  'press_box',
#  'gar',
#  'garages',
#  'Storage_Building',
#  'church;yes',
#  'Baboons_Home',
#  'Mixed_Use',
#  'housebuilding=house',
#  'arch',
#  'houses',
#  'house; commercial',
#  'cabin2',
#  'water_storage_tank',
#  'shed_and_seasonal_re',
#  'Private_Home_Owners_',
#  'commercial;apartment',
#  'retr',
#  'groundskeeping',
#  'guard station',
#  'train_wait_station',
#  'added building based',
#  'roof;yes',
#  'aquaculture',
#  'Classroom',
#  'hospital;yes',
#  'roof;apartments',
#  'glasshouse',
#  'poolhouse',
#  'town',
#  'airport_terminal',
#  'restrooms',
#  'tertiary_link',
#  'commercial;office;pa',
#  'ye\\',
#  'ret\\',
#  'Dentist_Office',
#  'roofe3',
#  'beverages',
#  'nursery',
#  'building:3',
#  'yes3',
#  'Clubhouse',
#  'Security_Hut',
#  'brick',
#  'bench',
#  'company_store',
#  'roof;residential',
#  'container',
#  'Mobile Home',
#  'school_district',
#  'destroyed',
#  'sto\\',
#  'friary',
#  'static caravan',
#  'manufactured_home',
#  'sport',
#  'apartments;commercia',
#  'detachedsource=digit',
#  'Depot',
#  'house;residential',
#  'storage_shed',
#  'Government',
#  'portable_toilet',
#  'railroad',
#  'allotment_house',
#  'deck',
#  'static_caravan',
#  'benches for sports',
#  'church;commercial',
#  'Laundry',
#  'amusement_ride',
#  'h',
#  'Tech 4',
#  'data_center',
#  'yes;civic',
#  'No',
#  'yes;college',
#  'alleyway',
#  'police_dept',
#  'toilet',
#  'hangar',
#  'retirement_home',
#  'rostrum',
#  'gathering_place',
#  'fee station',
#  'house;carport',
#  'Storage Units',
#  'support',
#  'village',
#  'pool_house',
#  'teepee',
#  'residential, buildin',
#  'salon',
#  'gazibo',
#  'civic',
#  'multi_office',
#  'changing_room',
#  'depot',
#  'sheds',
#  'Medical_Office',
#  'office;yes',
#  'tiny_house',
#  'houseaddr:city=Chula',
#  'water_works',
#  'siil',
#  'Administrative_and_R',
#  'bathhouse',
#  'funeral home',
#  'chruch',
#  'water_tank',
#  'Building',
#  'shopping center',
#  'storage_facility',
#  'cotton_gin',
#  'telecommunications',
#  'highrise',
#  'siko',
#  'monume',
#  'security',
#  'office;company',
#  'univeristy',
#  'institutional',
#  'barn;school',
#  'apartments;commerica',
#  'service_station',
#  'apartments;offices',
#  'done',
#  'Red_Barn',
#  'suburb',
#  'city',
#  'unclassified',
#  "Shoe_Attic,_Chef's_K",
#  'train_car',
#  'scientific',
#  'commercial;yes;retai',
#  'ramada',
#  'Public_Use',
#  'flat',
#  'gaq',
#  'Courthouse',
#  'Home',
#  'from old sat image',
#  'theater_arts_center',
#  'poultry_stable',
#  'observatory',
#  'Baldwin Building',
#  'Pool_House',
#  'commercial;house',
#  'valley',
#  'yes;grandstand',
#  'judging_booth',
#  'heath',
#  'synagogue',
#  'shed;garage;house',
#  'billboard',
#  'commercial;residenti',
#  'wood',
#  'small',
#  'corn_crib',
#  'Retirement_Community',
#  'tram',
#  'ward',
#  'YWCA',
#  'ye',
#  'garage;government',
#  'Recreational_Center',
#  'Alan',
#  'gabled',
#  'ses',
#  'burned_down',
#  'basilica',
#  'Public',
#  'skyscraper',
#  'drive-thru_atm',
#  'grist_mill',
#  'connector',
#  'servicem',
#  'gaza',
#  'Shelter',
#  'hunting,_fishing,_ca',
#  'Residential,_busines',
#  'yes;religious',
#  'drain',
#  'bridge',
#  'picnic shelter',
#  'clothes',
#  'Park_Maintenance',
#  'gate',
#  'shed',
#  'complex',
#  'lock_gate',
#  'masons',
#  'weir',
#  'water_mill',
#  'Cow Creek Road',
#  'administration',
#  'suites',
#  'mixed use',
#  'roof=no',
#  'boxcar',
#  'yes;retail',
#  'Grocery',
#  'office;roof',
#  'telecom',
#  'track_grade2',
#  'snack_bar',
#  'family_house',
#  'Title Company',
#  'storage-self',
#  'coffee shop',
#  'for-sale',
#  'retail\\',
#  'courtyard',
#  'Pumping_Station',
#  'type',
#  'dam',
#  'triumphal_arch',
#  'hut;gazebo',
#  'Townhome',
#  'h\\',
#  'Casa hermana',
#  'grange',
#  'exhibition_hall',
#  'Bed_and_Breakfast',
#  'roof;commercial',
#  'trailer',
#  'springhouse',
#  'carwash',
#  'hallway',
#  'rest',
#  'covered',
#  'sports',
#  'retail;yes',
#  'office;clubhouse',
#  'screen',
#  'yes_under_constructi',
#  'block',
#  'roofs',
#  'riding_hall',
#  'storage_tank',
#  'rest_room',
#  'pavilion',
#  'industrial, building',
#  'cabin4',
#  'Fraternal institutio',
#  'Telescope_dome',
#  'strip mall',
#  'multipurpose',
#  'yew',
#  'Military_Installatio',
#  'Pharmacy',
#  'stadium;yes',
#  'House 1',
#  'stream',
#  'collapsed',
#  'carport',
#  'shooting_stand',
#  'roof;kindergarten',
#  'Verizon Building',
#  'Coffee Kiosk',
#  'ruins',
#  'yes;roof',
#  'school, office',
#  'cyes',
#  'military',
#  'com',
#  'five',
#  'surface',
#  'food_truck',
#  'stairs',
#  'Convent',
#  'airplane',
#  'retaiil',
#  'Buiding',
#  'wayside_cross',
#  'garage\\',
#  'pedestrian',
#  'bandshell',
#  'Educational',
#  'pri',
#  'drive-through',
#  'yesm',
#  'Eugene Belisle Hall',
#  'bleachers',
#  'warehouse;government',
#  'picnic_shelter',
#  'vehicle',
#  'ware',
#  'field_house',
#  'tavern',
#  'transformer_tower',
#  'subway',
#  'public',
#  'foundations',
#  'Cabin',
#  'FIXME: Business',
#  'Ohio_University',
#  'detached;yes',
#  'manufacturing',
#  'hush_house',
#  'roof;university',
#  'commercial,_storage',
#  'university;yes',
#  'yesbuilding=house',
#  'commercial;greenhous',
#  'manufacture',
#  'loading ramp',
#  'school;historic',
#  'apartments;office',
#  'recreation_center',
#  'mausoleum',
#  'Sports',
#  'power',
#  'salt_dome',
#  'veranda',
#  'Lucky Friday',
#  'x',
#  'adobe',
#  'plant_nursery',
#  'park shelter',
#  'house;apartments',
#  'Market',
#  'Tower',
#  'Roof',
#  'gaz',
#  'Building_can_be_seen',
#  'yes; roof',
#  'yes;dormitory',
#  'inside',
#  'Morse PL',
#  'masonic_lodge',
#  'yes;industrial',
#  'Retail_and_Pharmacy',
#  'mini_roundabout',
#  'Boat_House',
#  'government;yes',
#  'restored_replica',
#  'folly',
#  'Utility_Suubstation',
#  'movable',
#  'distributor',
#  'Public_use',
#  'wastewater_plant',
#  'commerciaretail',
#  'carports',
#  'yes;offices',
#  'cabin0',
#  'stand',
#  'school;yes',
#  'national_capital',
#  'ROOF',
#  'roof;hotel',
#  'block house',
#  'group housing',
#  'water_well',
#  'triplex',
#  'pool maintnence',
#  'sport_stand',
#  'trellis',
#  'Condos',
#  "h'",
#  'Office',
#  'athletic',
#  'roof',
#  'gazebo',
#  'Government_Facility',
#  'Salt_Shed',
#  'root',
#  'digester',
#  'track_grade4',
#  'yes;residential',
#  'ab',
#  'loafing_shed',
#  'yes; commercial; yes',
#  'greenhouse',
#  'ROO',
#  'control_tower',
#  'mortuary',
#  'administrative',
#  'retail/residential',
#  'Hanger',
#  'coommercial',
#  'miniature_railway',
#  'barge',
#  'guard_house',
#  'religious;yes',
#  'Mitchum Basketball P',
#  'Parking_Attendant_Bo',
#  'yes,_cabin',
#  'sil\\',
#  'National_Guard',
#  'scoring_box',
#  'barns',
#  'Public_Works',
#  'ou',
#  'part=porch',
#  'slurry_tank',
#  'commercial;hotel',
#  'Changing_rooms/bathr',
#  'chu\\',
#  'Office_and_Residenti',
#  'art_studio',
#  'true',
#  'Natatorium',
#  'yes;church',
#  'apartments;bridge',
#  'primary',
#  'fence',
#  'Engineering_Building',
#  'detached',
#  'ret]',
#  'cow_barn',
#  'abandoned',
#  'decoration',
#  'use:residential',
#  'Rescue_Squad',
#  'locomotive',
#  'Business',
#  'Silo',
#  'Cultural_Center',
#  'Esko Bus Barnes',
#  'tipi',
#  'Guard_House',
#  'projector',
#  'farm_auxiliary',
#  'dining',
#  'Mausoleum',
#  'organization',
#  'trader',
#  'chu]',
#  'boiler_house',
#  'storages',
#  'staircase',
#  'maintenance_shop',
#  'tower_block',
#  'Duplex',
#  'laundry_room',
#  'sn',
#  'self-storage',
#  'none',
#  'stadium seating',
#  'aircraft',
#  'feed barn',
#  'yes;school',
#  'law enforcement',
#  'ruins;barn',
#  'fire_hydrant',
#  'Aquarium',
#  'multiple_local_gover',
#  'Yoga_Studio',
#  'yes;apartments',
#  'cover',
#  'planned',
#  'outdoor stage',
#  'Oratory',
#  'chicken_house',
#  'H',
#  'Castle_Hill_Electric',
#  'underground',
#  'Alba Public School',
#  'disused:yes',
#  'commecial',
#  'Club_House',
#  'warehouse',
#  'allotments',
#  'Learning_Center/_Day',
#  'u',
#  'yes;hut',
#  'carport;garage',
#  'skyway',
#  'gf',
#  ...}

# %%
map_file_path = os.path.abspath(os.path.join(geo_map_path, os.pardir))

# %%
pd.DataFrame({"new_label":list(new_list - old_list)}).to_csv(os.path.join(map_file_path, "new_label_list.csv"))

# %% [markdown]
# #### 4.1 New unclassified labels in layer

# %%
layer_to_check = ["buildings","pois"]

# %%
label_dict = {"raw_data_labels": {}, "organized_data_labels": {}}

# %%
start = time.time()
for layer in layer_to_check:
    print(layer)
    raw_list = set()
    organized_list = set()
    
    # raw data label
    for state in state_list:
        print(state)
        state_folder_path = os.path.join(unzipped_folder_path, state)
        state_shapefile_path = os.path.join(state_folder_path, "gis_osm_"+ layer + "*.shp")
        shapefile_finding_list = list(glob(state_shapefile_path))

        for p_shapefile in shapefile_finding_list:
            shpfile_df = gpd.read_file(p_shapefile)
            column_to_check = ["fclass", "type"]
            column_to_check = list(set(shpfile_df.columns).intersection(column_to_check))

            if len(column_to_check) > 1:
                if len(shpfile_df['fclass'].unique()) > len(shpfile_df['type'].unique()):
                    column_to_check = "fclass"
                else:
                    column_to_check = "type"
            else:
                column_to_check = column_to_check[0]
                
            new_labels = set(shpfile_df[column_to_check].unique())
            raw_list = raw_list.union(new_labels)
            
    # organized data label
    for lvl1 in os.listdir(organized_data_folder_path):
        print(lvl1)
        lvl1_path = os.path.join(organized_data_folder_path, lvl1)
        for lvl2 in os.listdir(lvl1_path):
            lvl2_path = os.path.join(lvl1_path, lvl2)
            for lvl3 in os.listdir(lvl2_path):
                lvl3_path = os.path.join(lvl2_path, lvl3)
                for target_file in glob(os.path.join(lvl3_path, "*"+layer+"*.shp")):
                    shpfile_df = gpd.read_file(target_file)
                    column_to_check = ["fclass", "type"]
                    column_to_check = list(set(shpfile_df.columns).intersection(column_to_check))

                    if len(column_to_check) > 1:
                        if len(shpfile_df['fclass'].unique()) > len(shpfile_df['type'].unique()):
                            column_to_check = "fclass"
                        else:
                            column_to_check = "type"
                    else:
                        column_to_check = column_to_check[0]

                    new_labels = set(shpfile_df[column_to_check].unique())
                    organized_list = organized_list.union(new_labels)
                    
    label_dict["raw_data_labels"][layer] = list(raw_list)
    label_dict["organized_data_labels"][layer] = list(organized_list)
    
end = time.time()
print(f"Runtime of the program is {end - start}")
# Out:
# buildings
# alabama
# alaska
# arizona
# arkansas
# norcal
# socal
# colorado
# connecticut
# delaware
# district of columbia
# florida
# georgia
# hawaii
# idaho
# illinois
# indiana
# iowa
# kansas
# kentucky
# louisiana
# maine
# maryland
# massachusetts
# michigan
# minnesota
# mississippi
# missouri
# montana
# nebraska
# nevada
# new hampshire
# new jersey
# new mexico
# new york
# north carolina
# north dakota
# ohio
# oklahoma
# oregon
# pennsylvania
# puerto rico
# rhode island
# south carolina
# south dakota
# tennessee
# texas
# united states virgin islands
# utah
# vermont
# virginia
# washington
# west virginia
# wisconsin
# wyoming
# busines
# commercial
# recreational
# residential
# service
# pois
# alabama
# alaska
# arizona
# arkansas
# norcal
# socal
# colorado
# connecticut
# delaware
# district of columbia
# florida
# georgia
# hawaii
# idaho
# illinois
# indiana
# iowa
# kansas
# kentucky
# louisiana
# maine
# maryland
# massachusetts
# michigan
# minnesota
# mississippi
# missouri
# montana
# nebraska
# nevada
# new hampshire
# new jersey
# new mexico
# new york
# north carolina
# north dakota
# ohio
# oklahoma
# oregon
# pennsylvania
# puerto rico
# rhode island
# south carolina
# south dakota
# tennessee
# texas
# united states virgin islands
# utah
# vermont
# virginia
# washington
# west virginia
# wisconsin
# wyoming
# busines
# commercial
# recreational
# residential
# service
# Runtime of the program is 2407.9099309444427

# %%
label_dict.keys()
# Out:
# dict_keys(['raw_data_labels', 'organized_data_labels'])

# %%
label_dict['raw_data_labels'].keys()
# Out:
# dict_keys(['buildings', 'pois'])

# %%
def compare_label_list(raw_list, organized_list):
    excluded_list = []
    raw_list_clean = clean_tag_column(pd.Series(raw_list))
    for rlabel in raw_list_clean:
        for olabel in organized_list:
            if olabel in rlabel:
                break
        else:
            excluded_list.append(rlabel)
    return excluded_list

# %%
label_dict['excluded_data_labels'] = dict()
for layer in layer_to_check:
    raw_list = label_dict['raw_data_labels'][layer]
    raw_list = [x for x in raw_list if x is not None]
    organized_list = label_dict['organized_data_labels'][layer]
    label_dict['excluded_data_labels'][layer] = compare_label_list(raw_list, organized_list)

# %%
map_file_path = os.path.abspath(os.path.join(geo_map_path, os.pardir))

excluded_label_dict_path = os.path.join(map_file_path, "excluded_label_dict.json")

with open(excluded_label_dict_path, 'w') as fp:
    json.dump(label_dict, fp)

# %%
label_dict['excluded_data_labels']['buildings']
# Out:
# ['salt_dome',
#  'proposed',
#  'remnant',
#  'cottage_front',
#  'plant',
#  'printing_facility',
#  'musuem',
#  'commecial',
#  'yew',
#  'temple',
#  'emergency_generator',
#  'yesm',
#  'ware',
#  'gazebo;roof',
#  'dismantled',
#  'no',
#  'musem',
#  'none',
#  'dam',
#  'train_car',
#  'recre',
#  'vehicle',
#  'spor',
#  'adobe',
#  'bq',
#  'composting_system',
#  'dugout',
#  'razed',
#  'grange',
#  'civic',
#  'ou',
#  'aerobridge',
#  'mausoleum',
#  'roof;ye',
#  'mechanical_room',
#  "stable'",
#  'physical_plant_(pp)',
#  'yes_but_the_burgee_b',
#  'dining',
#  'bho',
#  'refectory',
#  'disused:ye',
#  'true',
#  'romney',
#  'institutional',
#  'administrative_and_r',
#  'root',
#  'mil',
#  'sumter_psychiatry_a',
#  'steam_plant',
#  'cottage',
#  'dt',
#  'empty',
#  'tipi',
#  'amenity',
#  'rof',
#  'lucerne_ave_walk',
#  'ground',
#  'sidewalk',
#  'transmitter',
#  'john_mclain_lbra_leg',
#  'gf',
#  's3',
#  'floating',
#  'morse_th',
#  'amenity_center',
#  'liberty_dialysi',
#  'container',
#  'tower_1',
#  'inu',
#  'part',
#  'grandstand',
#  'schh',
#  're',
#  'outdoor_seating',
#  'telescope',
#  'roofe3',
#  'weapon_armory',
#  'ret\\',
#  'historical',
#  'univesity',
#  'wall',
#  'television_station',
#  'mixed_use',
#  'ski_jump',
#  'kennel',
#  'armory',
#  'observatory',
#  'laboratory_and_clas',
#  'projector',
#  'ind',
#  'stair',
#  'sile',
#  'paddock',
#  'drive_through',
#  'roof',
#  'contamination_cell',
#  'dealership',
#  'derelict,_uninhabite',
#  'hosue',
#  'gaq',
#  'ye',
#  'skyway',
#  'restroom',
#  'carport',
#  'charitable_organizat',
#  'wood',
#  'dome',
#  'aban',
#  'granite_fall',
#  '\\',
#  'monume',
#  'data',
#  'corn_crib',
#  'portable_toilet',
#  'waste_disposal',
#  'emergency',
#  'gazebo',
#  'restroom',
#  'gate',
#  'critical_infrastruct',
#  'ger',
#  'instructional',
#  "danny's_bass_boat_sh",
#  'cover',
#  'sheepfold',
#  'friary',
#  'veranda',
#  'staircase',
#  'rostrum',
#  'stationary_caravan',
#  'yes,_latrine',
#  'crossing',
#  'groundskeeping',
#  'multi-tennant_commer',
#  'rppf',
#  'anchorage',
#  'fixme:_busines',
#  'tank',
#  'unknown',
#  'roiof',
#  'folly',
#  'cage',
#  'carport;ye',
#  'static_railcar',
#  'shed,_detached',
#  'ski_jump',
#  'hvac',
#  'business/kavanaugh_c',
#  'carousel',
#  'resturant',
#  'ga',
#  'suite',
#  'garbage_shed',
#  'recreational',
#  'cov',
#  'ro',
#  'roof',
#  'hm',
#  'yt',
#  'yes;carport',
#  'resturant',
#  ']',
#  'tower_block',
#  'parish',
#  'utility_suubstation',
#  'burial_vault',
#  'usu',
#  'tribune',
#  'pumping_station',
#  'lifeguard_tower',
#  'i',
#  'apa',
#  'inside',
#  'carwash',
#  'main',
#  'rec_center',
#  'radio_station',
#  'parsonage',
#  'fixme:_unknown',
#  'grandslam',
#  'checkpoint',
#  'toilet',
#  'yer',
#  'national_guard',
#  'stable',
#  'aeroplane',
#  'convent',
#  'athletic',
#  'terminal_a_jetblue_p',
#  'pumping_station',
#  'walkway',
#  'buiding',
#  'jerry_siegel_lane',
#  'drive_through',
#  'teepee',
#  'awning',
#  'railway_shed',
#  'h',
#  'yesa',
#  'rest_room',
#  'fidelity',
#  'mason',
#  'dhop',
#  'non-profit',
#  'pri',
#  'demolished',
#  'banquet_hall',
#  'flat',
#  'booth',
#  'yes;_roof',
#  'duplex',
#  'cotton_gin',
#  'amusement_ride',
#  'retaiil',
#  'vacancy',
#  'press_box',
#  'gazibo',
#  'triumphal_arch',
#  'granary',
#  'sto',
#  'don_chief_denmyer_fa',
#  'baseball_dugout',
#  'gaz',
#  'covered_area',
#  'alleyway',
#  'suite',
#  'fourplex',
#  'trailer',
#  'salon',
#  'suite_212,_waverly_p',
#  'structure_added,_not',
#  'gh',
#  'gar',
#  'yard',
#  'elevator',
#  'wayside_shrine',
#  'gabled',
#  'comm',
#  'locomotive',
#  'plane',
#  'sg',
#  'highrise',
#  'roo',
#  'funeraria',
#  'tower',
#  'bandstand',
#  "h'",
#  'rescue_squad',
#  'crycc',
#  'sh',
#  'heiau',
#  'horse_facility',
#  'shooting_stand',
#  'damaged',
#  'complex',
#  'carp',
#  'bradbury_place',
#  'indzustrial',
#  'riding_hall',
#  'abandoned',
#  'se',
#  'telecom',
#  'shelt',
#  'outdoor;ye',
#  'chu',
#  'boat',
#  'historic',
#  'gathering_place',
#  'lesiure',
#  'pool_maintnence',
#  'build',
#  'hanger',
#  'chu]',
#  'chur',
#  'part=porch',
#  'datacenter',
#  'silo',
#  'mausoleum',
#  'bleacher',
#  'vfw',
#  'ranch',
#  'meeting_room',
#  'scoring_box',
#  'p',
#  'x',
#  'connector',
#  'concession_stand',
#  'fire_hydrant',
#  'ew',
#  'foundation',
#  'hall',
#  'balcony',
#  'mill',
#  'lucky_friday',
#  'arch',
#  'mobile',
#  'produce',
#  'sroof',
#  'from_old_sat_image',
#  'canopy',
#  'covered_arena',
#  'out',
#  'multiple_local_gover',
#  'gasstation',
#  'gazebo',
#  'yes:disused',
#  'yes;roo',
#  'yes;roof',
#  'yb',
#  'rest',
#  'administrative/auxil',
#  'presbyterian',
#  'step',
#  'busines',
#  'gazeboo',
#  'skyway',
#  'bayview_south',
#  'ward',
#  'guard_shack',
#  'pier',
#  'cistern',
#  'brick',
#  'commrcial',
#  'yes;shed',
#  'riverboat',
#  'synagogue',
#  'disused',
#  'shipping_container',
#  'ab',
#  'dining/instructional',
#  'substation',
#  'parish_hall',
#  'sign',
#  'winery',
#  'yesq',
#  'some_kind_of_structu',
#  'cye',
#  'outdoor_structure',
#  'sauna',
#  'gazeebo',
#  'cabana',
#  'townhosue',
#  'ret',
#  'ski_jump',
#  'terr',
#  'q',
#  'g',
#  'antique_auto_repair',
#  'salon',
#  'univeristy',
#  'emergency',
#  'changing_room',
#  'mixed_use',
#  'renovation',
#  'crayfish_lab',
#  'mechanical_room',
#  'chimney',
#  'rail_car',
#  'slipway',
#  'exhibition_hall',
#  'yert',
#  'generator',
#  'retirement_community',
#  'bridge;roof',
#  'nonprofit_center',
#  'hg',
#  'burned_down',
#  'platform',
#  'function_hall',
#  'basilica',
#  'chuch',
#  'grist_mill',
#  'fee_station',
#  'borough_hall',
#  'archaeological_site',
#  'meat_packing',
#  'multipurpose',
#  'kingdom_hall',
#  'covered_basketball_c',
#  'roof_overhang',
#  'r',
#  'hoouse',
#  'gasometer',
#  'military_installatio',
#  'fitne',
#  'sleeper_car',
#  'courtyard',
#  'cargo_terminal',
#  'roof',
#  'stage',
#  'wing',
#  'disused:terrace',
#  'leisure',
#  'social_facility',
#  'key',
#  'hr',
#  'rood',
#  'roof',
#  'restroom',
#  'army_national_guard',
#  'greandstand',
#  'fraternal_institutio',
#  'sugar_shack',
#  'chruch',
#  'utilitie',
#  'poultry_stable',
#  'depot',
#  'lib',
#  'circu',
#  'five',
#  'bri',
#  'railroad',
#  'wolfe_5',
#  'hq',
#  'leonard',
#  'new',
#  'maintenence',
#  'h',
#  'te',
#  'sto\\',
#  'telescope_dome',
#  'stable',
#  'nursing_facility',
#  'underground',
#  'nuclear',
#  'detached;ye',
#  'probably',
#  'security_booth',
#  'clarifier',
#  'billboard',
#  'flour_mill',
#  'ventilation_shaft',
#  'train',
#  'hunting,_fishing,_ca',
#  'seating',
#  'depot',
#  'block',
#  'y',
#  'changing_room',
#  'deck',
#  'ho',
#  'tabernacle',
#  'shedm',
#  'off',
#  'o',
#  'windmill',
#  'construction',
#  'marquee',
#  'gallery',
#  'hangar',
#  'dispatch',
#  'mitchum_basketball_p',
#  'hot',
#  'shed_and_seasonal_re',
#  'turning_circle',
#  'iy',
#  'chr',
#  'urban_pioneer',
#  'recreation',
#  'stand',
#  'roof=no',
#  'cowshed',
#  'private',
#  'learning_center/_day',
#  'masonic',
#  'toilet',
#  'ywa',
#  'digester',
#  'bathroom',
#  'kennel',
#  'bing',
#  'modular',
#  'car',
#  'kwick_stop_coin_op_l',
#  'rectory',
#  'social_hall',
#  'aquaculture',
#  'tavern',
#  'fire_lookout',
#  'stable;ye',
#  'entrance',
#  'retr',
#  'hye',
#  'nail',
#  'kennel',
#  'covered',
#  'mail_box_shed',
#  'boxcar',
#  'foundation',
#  'pool',
#  'tech_3',
#  'prision',
#  'data_center',
#  'utility',
#  'medium',
#  'changing_rooms/bathr',
#  'r3_environmental',
#  'charity',
#  'coommercial',
#  'hopsital',
#  'mixed',
#  'no',
#  'tower_3',
#  'ret]',
#  'gathering',
#  'guard_station',
#  'textile_mill',
#  'wood',
#  'railway',
#  'j',
#  'h\\',
#  'yesr',
#  'tent',
#  'covered_area',
#  'conservatory',
#  'station_1',
#  'open',
#  "shoe_attic,_chef's_k",
#  'bleacher',
#  'assisted_living_faci',
#  'meat_locker',
#  'control_tower',
#  'u',
#  'tech_cab',
#  'skywalk',
#  'station',
#  'toilet',
#  'g\\ho',
#  'movable',
#  'oratory',
#  'carillon',
#  'gov',
#  'caboose',
#  'comer',
#  'military',
#  'ywca',
#  'complete',
#  'ye\\',
#  'ymca',
#  'activity_center',
#  'eugene_belisle_hall',
#  'electricity',
#  'equinix',
#  'sch',
#  'outdoor_riser',
#  'faster_care',
#  'los_angeles_county_p',
#  'maintenance',
#  'work',
#  'administration',
#  'aprtment',
#  'generic',
#  'colocation',
#  'tractor_supply',
#  'agricultural',
#  'yw',
#  'no_longer_exist',
#  'the_maryland-nationa',
#  'convent',
#  'ferry',
#  'gravel_lot',
#  'hanger',
#  'tent',
#  'sty',
#  'pagoda',
#  'daycare',
#  'siil',
#  'antenna',
#  'yes;civic',
#  'main_terminal',
#  'loading_ramp',
#  'hor',
#  'toll_booth',
#  'mapillary',
#  'rec_center',
#  'kitchen',
#  'loafing_shed',
#  'chu\\',
#  'retai',
#  'bridge',
#  'detached_hangar',
#  'arbor',
#  'screen',
#  'cloister',
#  'auxiliary',
#  'silo',
#  'natatorium',
#  'historical_caboose',
#  'for-sale',
#  'commer',
#  'destroyed',
#  'tweak',
#  'quonset',
#  'manager_skagit_valle',
#  'ticketing',
#  'morse_pl',
#  'outer',
#  'stand',
#  'villa',
#  'shrine',
#  'rebuilt',
#  "ga'",
#  'vacant',
#  'forum',
#  'terraceqz',
#  'computer',
#  'mixd_use',
#  'campanile',
#  'latrine',
#  'terminal',
#  'business/organizatio',
#  'undefined',
#  'research',
#  'yes;grandstand',
#  'old_wentworth_elevat',
#  'mixed-use',
#  'bing',
#  'way',
#  'open_air',
#  'gas_pumps_under_awni',
#  'grandtand',
#  'salt_shed',
#  'station',
#  'trader',
#  'support',
#  'student_athlete_buil',
#  'triplex',
#  'sn',
#  'attached',
#  'pharmaceutical_compa',
#  'science_incubator',
#  'power',
#  'loading_dock',
#  'h]',
#  'terrace',
#  'aircraft',
#  'fixed_base_opperator',
#  'houe',
#  'housr',
#  'yesshed',
#  'airplane',
#  'pierce_county_buildi',
#  "y'",
#  'fire',
#  'place_of_worship',
#  'fence',
#  'portable',
#  'salt_pyramid',
#  "wagner'",
#  'collapsed',
#  'mortuary',
#  'airplane_fuselage',
#  'rv',
#  'portable',
#  'pedestrian',
#  'carriage_lane',
#  'ye',
#  'open_exposure',
#  'alan',
#  'planned',
#  'tower_2',
#  'e',
#  'h',
#  'tech_4',
#  'tower',
#  'pavillon',
#  'seat',
#  'dugout',
#  'palapa',
#  'room',
#  'distributor',
#  'tunnel',
#  'telecommunication',
#  'trelli',
#  'crime_fighters_car_w',
#  'semi',
#  'scientific',
#  'railway',
#  'chicken_coop',
#  'minor_part',
#  'concession_stand',
#  'natatorium',
#  'bench',
#  'smokery',
#  'valley',
#  'roo',
#  'hackerspace',
#  'tomb',
#  'accommodation',
#  'grandstand',
#  'sil\\',
#  'yes#texastech',
#  'column',
#  'train_wait_station',
#  'siko',
#  'ranch',
#  'arena',
#  'carport',
#  'judging_booth',
#  'bandshell',
#  'casa_hermana',
#  'furnace',
#  'townhall',
#  'drive-through',
#  'd',
#  'yes;detached',
#  'slurry_tank',
#  'shed',
#  'corridor',
#  'yurt',
#  'bu',
#  'primary',
#  'transformer_tower',
#  'train_car',
#  'type',
#  'portico',
#  'occupied',
#  'ga',
#  'event_center',
#  'g',
#  'pavilion',
#  'patio',
#  'structure',
#  'surface',
#  'duplex',
#  'jeweler',
#  'yes3',
#  'ship',
#  'name',
#  'utility',
#  'unkown',
#  'gaza',
#  'detached',
#  'detachedsource=digit',
#  'hipped',
#  'yes_under_constructi',
#  'bunker',
#  'busines',
#  'shed',
#  'ramada',
#  'cow_creek_road',
#  'security',
#  'demountable',
#  'porch',
#  'doityourself',
#  'gated',
#  'decoration',
#  'aba',
#  'law_enforcement',
#  'administrative',
#  'com',
#  'municiple',
#  'dump_station',
#  'rocket',
#  's\\',
#  'mixed_use',
#  '',
#  'hallway',
#  'done',
#  'manor',
#  'telescope_dome',
#  'skybridge']

# %% [markdown]
# ### 5. Combine files for states and layers

# %%
start = time.time()
start = 0
for lvl1 in os.listdir(organized_data_folder_path):
    print(lvl1)
    lvl1_path = os.path.join(organized_data_folder_path, lvl1)
    for lvl2 in os.listdir(lvl1_path):
        print("  "+lvl2)
        lvl2_path = os.path.join(lvl1_path, lvl2)
        for lvl3 in os.listdir(lvl2_path):
            print("    "+lvl3)
            if lvl3 == "house":
                start = 1
            if start == 0:
                continue
            
            lvl3_path = os.path.join(lvl2_path, lvl3)
            df_point = pd.DataFrame()
            df_polygon = pd.DataFrame()
            df_folder_path = os.path.join(combined_data_folder_path, lvl1, lvl2, lvl3)
            create_folder(df_folder_path)
            df_point_path = os.path.join(df_folder_path, lvl3+"_point.shp")
            df_line_path = os.path.join(df_folder_path, lvl3+"_line.shp")
            df_polygon_path = os.path.join(df_folder_path, lvl3+"_polygon.shp")
            
            if not os.path.exists(df_point_path):
                for target_file in glob(os.path.join(lvl3_path, "*point.shp")):
                    shpfile_df = gpd.read_file(target_file)
                    df_point = df_point.append(shpfile_df)
                if df_point.shape[0] >0:
                    df_point['geo_type'] = [type(x) for x in df_point.geometry]
                    df_line = df_point[df_point['geo_type'] == shapely.geometry.linestring.LineString]
                    if df_line.shape[0] >0:
                        df_point = df_point[df_point['geo_type'] == shapely.geometry.point.Point]
                        df_line.reset_index(inplace=True, drop=True)
                        df_point.reset_index(inplace=True, drop=True)
                        df_point = df_point.drop('geo_type', 1)
                        df_line = df_line.drop('geo_type', 1)
                        if df_point.shape[0] >0:
                            df_point.to_file(df_point_path)
                        df_line.to_file(df_line_path)
                    else:
                        df_point = df_point.drop('geo_type', 1)
                        df_point.reset_index(inplace=True, drop=True)
                        df_point.to_file(df_point_path)

            
            if not os.path.exists(df_polygon_path):
                for target_file in glob(os.path.join(lvl3_path, "*polygon.shp")):
                    shpfile_df = gpd.read_file(target_file)
                    df_polygon = df_polygon.append(shpfile_df)
                if df_polygon.shape[0] >0:
                    df_polygon.reset_index(inplace=True, drop=True)
                    df_polygon.to_file(df_polygon_path)
                
end = time.time()
print(f"Runtime of the program is {end - start}")
# Out:
# busines
#   busines
#     company
#     convention_center
#     factory
#     industrial
#     office
# commercial
#   food
#     bakery
#     beverage
#     cafe
#     deli
#     dining_hall
#     fast_food
#     food
#     restaurant
#   leisure
#     aquarium
#     bar
#     casino
#     cinema
#     museum
#     theatre
#     theme_park
#     zoo
#   lifestyle
#     beauty_shop
#     car_wash
#     hotel
#     laundry
#     recycling
#     self_storage
#     stadium
#     travel_agent
#     veterinary
#   other
#     commercial
#   shopping
#     kiosk
#     mall
#     shop
#     supermarket
# recreational
#   indoor
#     sports_centre
#     swimming_pool
#   outdoor
#     attraction
#     bicycle_rental
#     camp_site
#     country_club
#     dog_park
#     farm
#     golf_course
#     graveyard
#     hunting_stand
#     ice_rink
#     nature
#     park
#     picnic_site
#     pitch
#     playground
#     shelter
#     tennis_court
#     tourism
#     track
#     viewpoint
#     water
# residential
#   building
#     building
#   residential
#     apartment
#     dormitory
#     home
#     house
#     residential
# service
#   education
#     childcare
#     college
#     education
#     kindergarten
#     library
#     preschool
#     school
#     university
#   finance
#     atm
#     bank
#     insurance
#   health
#     clinic
#     dentist
#     doctor
#     health
#     health_center
#     hospital
#     medical
#     mental_health_clinic
#     nursing_home
#     pharmacy
#   other
#     community_centre
#     fire_station
#     government
#     police
#     post_office
#     prison
#     public_building
#     telephone
#   religion
#     religion
#   transportation
#     airport
#     bus_station
#     car_rental
#     ferry_terminal
#     fuel
#     parking
#     parking_bicycle
#     taxi
#     train_station
#     transportation
# Runtime of the program is 1655579462.8025546

# %%
map_dict['map']['service']
# Out:
# {'education': {'college': ['college_building'],
#   'childcare': ['childcare_facility', 'day_care'],
#   'preschool': [],
#   'kindergarten': [],
#   'school': ['high_school', 'music_school', 'classroom'],
#   'library': ['university_library'],
#   'university': [],
#   'education': ['academic', 'academic_building', 'student_center']},
#  'health': {'clinic': [],
#   'dentist': ['dentist_office'],
#   'doctor': ['doctor'],
#   'hospital': [],
#   'pharmacy': [],
#   'health_center': [],
#   'nursing_home': [],
#   'medical': [],
#   'health': ['healthcare'],
#   'mental_health_clinic': []},
#  'religiou': {'buddhist': ['christian',
#    'christian_anglican',
#    'christian_catholic',
#    'christian_evangelical',
#    'christian_lutheran',
#    'christian_methodist',
#    'christian_orthodox',
#    'christian_protestant',
#    'hindu',
#    'jewish',
#    'muslim',
#    'muslim_shia',
#    'muslim_sunni',
#    'sikh',
#    'taoist',
#    'cathedral',
#    'chapel',
#    'church',
#    'monastery',
#    'mosque',
#    'religion',
#    'presbytery',
#    'religiou',
#    'fraturnity',
#    'presbyterian\n']},
#  'transportation': {'transportation': [],
#   'airport': ['airfield', 'helipad', 'apron'],
#   'bus_station': ['bus_stop'],
#   'train_station': ['railway_station',
#    'railway_halt',
#    'tram_stop',
#    'subway_entrance'],
#   'car_rental': ['car_sharing'],
#   'taxi': ['taxi_rank'],
#   'ferry_terminal': [],
#   'fuel': ['service', 'gas_station'],
#   'parking': ['garage',
#    'parking_multistorey',
#    'parking_underground',
#    'vending_parking',
#    'parking_site',
#    'parking_lot',
#    'car_park',
#    'parking_structure',
#    'parking_space'],
#   'parking_bicycle': []},
#  'finance': {'bank': ['credit_union'], 'atm': [], 'insurance': []},
#  'other': {'government': ['courthouse',
#    'embassy',
#    'municipal',
#    'town_hall',
#    'city_hall',
#    'municipial'],
#   'police': ['police_station'],
#   'post_office': ['post_box', 'us_post_office'],
#   'community_centre': ['community_center'],
#   'fire_station': ['fire_department'],
#   'prison': ['jail_house', 'jail'],
#   'telephone': [],
#   'public_building': []}}

# %% [markdown]
# ### 6. check point and polygon shpfile relationship

# %%
start = time.time()
for lvl1 in os.listdir(organized_data_folder_path):
    print(lvl1)
    lvl1_path = os.path.join(organized_data_folder_path, lvl1)
    for lvl2 in os.listdir(lvl1_path):
        print("  "+lvl2)
        lvl2_path = os.path.join(lvl1_path, lvl2)
        for lvl3 in os.listdir(lvl2_path):
            print("    "+lvl3)
            lvl3_path = os.path.join(lvl2_path, lvl3)
            df_point = pd.DataFrame()
            df_polygon = pd.DataFrame()
            df_folder_path = os.path.join(combined_data_folder_path, lvl1, lvl2, lvl3)

            df_point_path = os.path.join(df_folder_path, lvl3+"_point.shp")
            df_line_path = os.path.join(df_folder_path, lvl3+"_line.shp")
            df_polygon_path = os.path.join(df_folder_path, lvl3+"_polygon.shp")
            
            if not os.path.exists(df_point_path):
                for target_file in glob(os.path.join(lvl3_path, "*point.shp")):
                    shpfile_df = gpd.read_file(target_file)
                    df_point = df_point.append(shpfile_df)
                    
            if not os.path.exists(df_polygon_path):
                for target_file in glob(os.path.join(lvl3_path, "*polygon.shp")):
                    shpfile_df = gpd.read_file(target_file)
                    df_polygon = df_polygon.append(shpfile_df)
                    
            break
        break
    break
end = time.time()
print(f"Runtime of the program is {end - start}")
# Out:
# busines
#   busines
#     company
# Runtime of the program is 0.0949392318725586

# %%
amenity = "university"

# %%
point_file_path = r"D:\data\Geofabrik\organized_landmarks_combined\service\education\university\university_point.shp"
df_point = gpd.read_file(point_file_path)
polygon_file_path = r"D:\data\Geofabrik\organized_landmarks_combined\service\education\university\university_polygon.shp"
df_polygon = gpd.read_file(polygon_file_path)

# %%
df_point
# Out:
#          osm_id  code      fclass  \
# 0     358962262  2081  university
# 1     358974094  2081  university
# 2     358974322  2081  university
# 3     358985169  2081  university
# 4     360195422  2081  university
# ..          ...   ...         ...
# 635  4291080657  2081  university
# 636  4968819754  2081  university
# 637  5404250879  2081  university
# 638  5676069878  2081  university
# 639  6389062118  2081  university
#
#                                                name tag_col_ty  \
# 0                       University of South Alabama        str
# 1    Alabama Agricultural and Mechanical University        str
# 2                                Huntingdon College        str
# 3                       University of North Alabama        str
# 4                        Ludwig von Mises Institute        str
# ..                                              ...        ...
# 635  Medical College of Wisconsin-Central Wisconsin        str
# 636                            Concordia University        str
# 637    Concordia University Wisconsin-Beloit Center        str
# 638                     Kenosha County UW-Extension        str
# 639                            Concordia University        str
#
#                        geometry
# 0    POINT (-88.17973 30.69491)
# 1    POINT (-86.56842 34.78390)
# 2    POINT (-86.28525 32.35097)
# 3    POINT (-87.67920 34.80787)
# 4    POINT (-85.49100 32.60672)
# ..                          ...
# 635  POINT (-89.66383 44.96482)
# 636  POINT (-87.93287 42.56926)
# 637  POINT (-88.98947 42.52407)
# 638  POINT (-88.04467 42.56991)
# 639  POINT (-88.47183 44.26087)
#
# [640 rows x 6 columns]

# %%
df_polygon
# Out:
#           osm_id  code      fclass                      name        type  \
# 0       38744956  1500    building               Palmer Hall  university
# 1       38765023  1500    building           Humanities Hall  university
# 2       38765026  1500    building               Morgan Hall  university
# 3       38765029  1500    building               Farmer Hall  university
# 4       38765036  1500    building               Myrick Hall  university
# ...          ...   ...         ...                       ...         ...
# 32997  672415150  1500    building          Service Building  university
# 32998  673731502  1500    building  Bureau of Mines Building  university
# 32999  673731503  1500    building  Energy Innovation Center  university
# 33000  480272723  2081  university     University of Wyoming        None
# 33001  617073331  2081  university   Central Wyoming College        None
#
#       tag_col_ty                                           geometry
# 0            str  POLYGON ((-86.86289 33.10384, -86.86279 33.103...
# 1            str  POLYGON ((-86.86375 33.10572, -86.86370 33.105...
# 2            str  POLYGON ((-86.86369 33.10604, -86.86361 33.106...
# 3            str  POLYGON ((-86.86455 33.10611, -86.86455 33.106...
# 4            str  POLYGON ((-86.86544 33.10602, -86.86535 33.106...
# ...          ...                                                ...
# 32997        str  POLYGON ((-105.57850 41.31498, -105.57848 41.3...
# 32998        str  POLYGON ((-105.58505 41.31452, -105.58504 41.3...
# 32999        str  POLYGON ((-105.58334 41.31486, -105.58333 41.3...
# 33000        str  POLYGON ((-105.58566 41.31151, -105.58565 41.3...
# 33001        str  POLYGON ((-108.43013 43.03291, -108.43013 43.0...
#
# [33002 rows x 7 columns]

# %%
point_set = set(df_point.osm_id.unique())

# %%
polygon_set = set(df_polygon.osm_id.unique())

# %%
point_set.intersection(polygon_set)
# Out:
# set()

# %%
df_point[df_point['name'] == 'Laramie County Community College']
# Out:
# Empty GeoDataFrame
# Columns: [osm_id, code, fclass, name, tag_col_ty, geometry]
# Index: []
